# %% [markdown]
# <center> <h1> **Fraud Detection**</h1> <br>
# <h2>
# This is a simulated credit card transaction dataset created by an A.I. that has legitimate and fraudulent transactions during the span of *1st Jan 2019 - 31st Dec 2020.* <br> It contains the records of credit card purchases of 1000 customers doing transactions spanning from 800 different merchants. 	</h2></center>
# <p>
# 1. trans_date_trans_time<br>
# 2. cc_num<br>
# 3. merchant name<br>
# 4. category (of purchase type)<br>
# 5. amt (amount of purchase)<br>
# 6. first last (name)<br>
# 7. gender<br>
# 8. zip (zipcode of customer) ((probably don't need this if we convert the lat&long to zipcodes))<br>
# 9.	lat of customer home address(latitude)	<br>
# 10. long of cust home address(longitude)	<br>
# 11. city_pop of cust<br>
# 12.	job	<br>
# 13. dob(date of birth)<br>
# 14. trans_num(transaction number)<br>
# 15. unix_time	<br>
# 16. merch_lat	(merchant latitude)<br>
# 17. merch_long (merchant longitude)	<br>
# 18. is_fraud (binary classifier)<br>
# </p>

# %% [markdown]
# <center><h2> In this project will employ the Semi-Supervised Learning using the following techniques:</center></h2>
#
# 1. Stacking, boosting and bagging for creation of Meta-Classifiers
# 2. DNN and Keras metrics for imbalanced data
# 3. Random forest
# 4. Anomaly detection w/ LOF  &  Isolation Forest models
# 5. SVC
# 6. KNN clusters
# 7. Ridge Regression
# 8. Extra Trees
# 9. TSNE w/ KNN

# %% [markdown]
# #Import & Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import pandas
import pandas as pd
import seaborn as sns
from decimal import Decimal
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from scipy.stats import skew, boxcox
from sklearn.model_selection import train_test_split, learning_curve
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score
from sklearn.metrics import average_precision_score, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from xgboost.sklearn import XGBClassifier
from xgboost import plot_importance, to_graphviz
from sklearn.metrics import plot_confusion_matrix
from sklearn.svm import SVR
from sklearn.svm import SVC
import itertools
import time
from warnings import filterwarnings
from sklearn import ensemble
from sqlalchemy import create_engine
from scipy.stats import zscore
pd.options.display.float_format = '{:.2f}'.format
# %matplotlib inline

# %% [markdown]
# ###Exploratory dataset

# %%
#This is strictly to pull up unique() and nunique() after modifying our dataset later on
fraud_df = pd.read_csv('https://storage.googleapis.com/datasets_for_analysis/fraudTest%5B1%5D.csv', index_col = False, error_bad_lines=False)

#This code will create dummy columns for all the category options of purchases and rewrite the DF to be onehot encoded!
#fraud_df = pd.get_dummies(fraud_df, prefix='cat', prefix_sep='.', columns=['category'], drop_first=True)

#This will delete the first column which is just a row counter
fraud_df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %% [markdown]
# ###Dataset for modeling

# %%
#import csv files from the Google Storage Database
fraud_df_test = pd.read_csv('https://storage.googleapis.com/datasets_for_analysis/fraudTest%5B1%5D.csv', index_col = False, error_bad_lines=False)
#all code to pull up csv
fraud_df_train= pd.read_csv('https://storage.googleapis.com/datasets_for_analysis/fraudTrain.csv', index_col = False, error_bad_lines=False)

#Concat the dataframs together
fraud = pd.concat([fraud_df_train, fraud_df_test])
fraud.reset_index(drop=True, inplace=True)
fraud.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
fraud.head(1)
# Out:
#   trans_date_trans_time            cc_num  ... merch_long is_fraud
# 0   2019-01-01 00:00:18  2703186189652095  ...     -82.05        0
#
# [1 rows x 22 columns]

# %% [markdown]
# #Functions

# %%
#This is a great test to check for outliers
def grubbs_test(x):
    n = len(x)
    mean_x = np.mean(x)
    sd_x = np.std(x)
    numerator = max(abs(x-mean_x))
    g_calculated = numerator/sd_x
    print("Grubbs Calculated Value:",g_calculated)
    t_value = stats.t.ppf(1 - 0.05 / (2 * n), n - 2)
    g_critical = ((n - 1) * np.sqrt(np.square(t_value))) / (np.sqrt(n) * np.sqrt(n - 2 + np.square(t_value)))
    print("Grubbs Critical Value:",g_critical)
    if g_critical > g_calculated:
        print("From grubbs_test we observe that calculated value is lesser than critical value, Accept null hypothesis and conclude that there is no outliers\n")
    else:
        print("From grubbs_test we observe that calculated value is greater than critical value, Reject null hypothesis and conclude that there is an outliers\n")

#Simply boxplot
def Box_plots(df):
    plt.figure(figsize=(10, 4))
    plt.title("Box Plot")
    sns.boxplot(df)
    plt.show()

#Simple histogram plot
def hist_plots(df):
    plt.figure(figsize=(10, 4))
    plt.hist(df)
    plt.title("Histogram Plot")
    plt.show()

#Simple scatter plot
def scatter_plots(df1,df2):
    fig, ax = plt.subplots(figsize=(10,4))
    ax.scatter(df1,df2)
    ax.set_xlabel('Age')
    ax.set_ylabel('Fare')
    plt.title("Scatter Plot")
    plt.show()

#To get a tukey to help with outliers
def get_tukey(df,tukey_col):
    q75, q25 = np.percentile(df[tukey_col], [75 ,25])
    iqr = q75 - q25
    tukey_dict = {}
    for threshold in np.arange(1,5.5,0.5):
        min_val = q25 - (iqr*threshold)
        max_val = q75 + (iqr*threshold)
#        print("The score threshold is: {}".format(threshold))
        num_outliers = len((np.where((df[tukey_col] > max_val) | (df[tukey_col] < min_val))[0]))
#        print("Number of outliers is: {}".format(num_outliers))
        tukey_dict.update({threshold: [min_val, max_val, num_outliers]})
    return tukey_dict

#For a zscore 
def get_zscore(df,z_col):
    z_scores = zscore(df[z_col])
    z_dict = {}
    for threshold in range(1,5):
        print("The score threshold is: {}".format(threshold))
        print("The indices of the outliers:")
        outlier_indices = np.where(z_scores > threshold)
        print(outlier_indices)
        num_outliers = len((np.where(z_scores > threshold)[0]))
        print("Number of outliers is: {}".format(num_outliers))
        z_dict.update({threshold: outlier_indices})
    return z_dict

# %%
#Notice in the 'merchant' column for some reason the word 'fraud_' is printed infront of each retailer, let's remove that
fraud.replace("fraud_", "", regex=True, inplace=True) 
#Rename columns
fraud_df.rename(columns={'trans_date_trans_time': 'trans_date_time'}, inplace=True)

# %%
#Group columns for easier analysis
fraud['customer_name'] = fraud['first'] + [' '] + fraud['last']

# %%
#split the date time to two separate columns
fraud_df['trans_date_time'] = pd.to_datetime(fraud_df['trans_date_time']) 
fraud_df['date'] = fraud_df['trans_date_time'].dt.strftime('%d/%m/%Y')
#fraud_df_train['time'] = fraud_df_train['trans_date_time'].dt.strftime('%H:%M')

#Drop the trans_date_time column now that it's split
fraud_df.drop(columns='trans_date_time', inplace=True)
#Drop unnecessary columns
fraud.drop(columns=['city', 'state', 'street', 'first', 'last'], inplace=True)

# %% [markdown]
# #Exploratory Data Analysis

# %% [markdown]
# ##Check for duplicates

# %%
# Select duplicate rows except first occurrence based on all columns
duplicateRowsDF_train = fraud[fraud.duplicated()]
print("Duplicate Rows except first occurrence based on all columns are :")
print(duplicateRowsDF_train)
# Out:
# Duplicate Rows except first occurrence based on all columns are :
# Empty DataFrame
# Columns: [trans_date_trans_time, cc_num, merchant, category, amt, gender, zip, lat, long, city_pop, job, dob, trans_num, unix_time, merch_lat, merch_long, is_fraud, customer_name]
# Index: []

# %%
fraud.set_index(['customer_name'], inplace=True)

# %% [markdown]
# Check for nulls

# %%
#This will check to see the percentage of data that is null
fraud.isnull().sum()*100/fraud.isnull().count()
# Out:
# trans_date_trans_time   0.00
# cc_num                  0.00
# merchant                0.00
# category                0.00
# amt                     0.00
# gender                  0.00
# zip                     0.00
# lat                     0.00
# long                    0.00
# city_pop                0.00
# job                     0.00
# dob                     0.00
# trans_num               0.00
# unix_time               0.00
# merch_lat               0.00
# merch_long              0.00
# is_fraud                0.00
# dtype: float64

# %%
fraud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1852394 entries, Jennifer Banks to Samuel Frey
# Data columns (total 17 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   trans_date_trans_time  object
#  1   cc_num                 int64
#  2   merchant               object
#  3   category               object
#  4   amt                    float64
#  5   gender                 object
#  6   zip                    int64
#  7   lat                    float64
#  8   long                   float64
#  9   city_pop               int64
#  10  job                    object
#  11  dob                    object
#  12  trans_num              object
#  13  unix_time              int64
#  14  merch_lat              float64
#  15  merch_long             float64
#  16  is_fraud               int64
# dtypes: float64(5), int64(5), object(7)
# memory usage: 254.4+ MB

# %%
#Lets transform this column so that we can do some simple math
fraud_df['is_fraud'].astype(str).astype(int)

#Determine how much of the data is fraud vs normal transactions
fraud_true = fraud_df[fraud_df['is_fraud'] == 1]
fraud_true =  fraud_true.shape[0]
normal = fraud_df[fraud_df['is_fraud'] == 0]
normal = normal.shape[0]
print('The amount of fraudulent transactions in the dataset are: {}'.format(fraud_true))
print('The amount of normal transactions in the dataset are: {}'.format(normal))
print('The percentage of fraud in our training data is: {:.4f} %' .format(fraud_true/normal))
# Out:
# The amount of fraudulent transactions in the dataset are: 2145
# The amount of normal transactions in the dataset are: 553574
# The percentage of fraud in our training data is: 0.0039 %

# %% [markdown]
# ###*This data is highly unbalanced as only .4% of all transactions here are fraudulent, so it's literally going to be like finding a needle in a haystack. See figure below for a visual.

# %%
fraud.is_fraud.value_counts().plot(kind='bar', title='Count (is_fraud)');

# %% [markdown]
# <h3>This shows the distribution of purchase amounts for fraudulent transactions**</h3>

# %%
#Lets transform this back so that we can plot it
fraud_df['is_fraud'].astype(str).astype(object)
fraud_true = fraud_df[fraud_df['is_fraud'] == 1]
normal = fraud_df[fraud_df['is_fraud'] == 0]
fraud_true.amt.describe()
# Out:
# count   2145.00
# mean     528.36
# std      392.75
# min        1.78
# 25%      214.51
# 50%      371.94
# 75%      907.77
# max     1320.92
# Name: amt, dtype: float64

# %% [markdown]
# <h3>We see here that the max amount of a fraudulent purchase is only $1376**</h3>

# %%
normal.amt.describe()
# Out:
# count   553574.00
# mean        67.61
# std        152.47
# min          1.00
# 25%          9.60
# 50%         47.15
# 75%         82.62
# max      22768.11
# Name: amt, dtype: float64

# %% [markdown]
# <h3>We see here that the max amount of a normal purchase is only $22768**</h3>

# %% [markdown]
# ##Plot distribution of key columns

# %%
#Switch the column datatype back to object in order to call the hist function
fraud_explore = fraud_df[fraud_df['is_fraud'] == 1]
normal_explore = fraud_df[fraud_df['is_fraud'] == 0]

# amount comparison - How different is the amount of money used in different transaction classes?
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
bins = 30

ax1.hist(fraud_explore['amt'], bins=bins)
ax2.hist(normal_explore['amt'], bins=bins)

ax1.set_title('Fraud')
ax2.set_title('Normal')

ax1.set_xlabel('Amount ($)')
ax2.set_xlabel('Amount ($)')
ax1.set_ylabel('Number of Transactions')

ax2.set_ylim(0, 320)
plt.show()

# %% [markdown]
# <h3>As we can see, the non-fradulent list of purchase amounts has many outliers</h3>

# %% [markdown]
# ##Preprocessing unbalanced data

# %% [markdown]
# Categories of Purchase Distributions
# ---

# %% [markdown]
# The different categories that we can check for our model are:<br>
# personal_care', 'health_fitness', 'misc_pos', 'travel',
#        'kids_pets', 'shopping_pos', 'food_dining', 'home',
#        'entertainment', 'shopping_net', 'misc_net', 'grocery_pos',
#        'gas_transport', 'grocery_net'

# %%
#Create a copy of the df in order to do onehot encoding and save the original dataframe
categories = fraud[['category', 'gender']].copy()

#Get dummies for categories and gender
fraud_cat = pd.get_dummies(categories[['category', 'gender']], drop_first=True)

# %%
#Drop unnecessary column
#fraud.drop(fraud.category, axis=1, inplace=True)

#Combine the two arrays
fraud_cat.reset_index(drop=True, inplace=True)
fraud.reset_index(drop=True, inplace=True)
fraud = pd.concat([fraud, fraud_cat], axis=1, sort=False)
fraud.reset_index(drop=True, inplace=True)

# %%
# Class count
count_class_0, count_class_1 = fraud.is_fraud.value_counts()

#Determine how much of the data is fraud vs normal transactions
fraud_true = fraud_df[fraud_df['is_fraud'] == 1]
normal_true = fraud_df[fraud_df['is_fraud'] == 0]

# %%
#This will show us all of the fraudulent transactions in their respective categories

plt.figure(figsize=[10,10])
ax = fraud_true.groupby(['category', 'is_fraud']).size().plot(kind='bar')
ax.set_title("# of transaction which are the actual fraud per transaction type")
ax.set_xlabel("(Category, is_fraud)")
ax.set_ylabel("Count of transaction")
for p in ax.patches:
    ax.annotate(str(format(int(p.get_height()), ',d')), (p.get_x(), p.get_height()*1.01))

# %%
#This will show us all of the normal transactions in their respective categories

plt.figure(figsize=[10,10])
ax = normal_true.groupby(['category', 'is_fraud']).size().plot(kind='bar')
ax.set_title("# of transaction which are the actual fraud per transaction type")
ax.set_xlabel("(Category, Normal)")
ax.set_ylabel("Count of transaction")
for p in ax.patches:
    ax.annotate(str(format(int(p.get_height()), ',d')), (p.get_x(), p.get_height()*1.01))

# %%
plt.figure(figsize=(20, 10))
splot=sns.barplot(x="category", y="amt", hue="gender", palette="vlag", ci=None, data=fraud_true)
plt.ylabel("Mean Purchases in US Dollars", size=14)
plt.xlabel("Purchases", size=14)
plt.title("Barplot showing categorical purchases between men and women.", size=18)
for p in splot.patches:
    splot.annotate(format(p.get_height(), '.0f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=15,
                   xytext = (0, -12), 
                   textcoords = 'offset points')
plt.savefig('Categorical ',dpi=150)

# %% [markdown]
# ##Find Correlation

# %%
# correlate life expectancy to all variables:
corr = fraud_df.corr()

def draw_heatmap(df,corr_thresh=.5):
    """ Draws heatmap out of a dataframe. 
        Set corr_thresh to -1000 for full heatmap,
        or keep default for strong correlation
    """
    
    # make the correlation matrix.
    corr_mat = df.corr()

    # move the column to head of list using index, pop and insert
    cols = corr_mat.columns.to_list()
    print (cols)

    # reorder
    corr_mat = corr_mat.loc[:, cols]
    corr_mat.sort_values(by=['is_fraud'],ascending=False)

    # figure aesthetics
    plt.figure(figsize=(18,15))
    plt.plot()
    
    # draw the heatmap using seaborn.
    sns.heatmap(corr_mat[(corr_mat > corr_thresh)], square=True, annot=True, linewidths=.5)
    plt.title("Correlation Matrix (Fraud Detection Features)")
    print("**Correlation Matrix (filtered for correlation above {}):**".format(corr_thresh))
    plt.show()

draw_heatmap(fraud)
# Out:
# ['cc_num', 'amt', 'zip', 'lat', 'long', 'city_pop', 'unix_time', 'merch_lat', 'merch_long', 'is_fraud', 'category_food_dining', 'category_gas_transport', 'category_grocery_net', 'category_grocery_pos', 'category_health_fitness', 'category_home', 'category_kids_pets', 'category_misc_net', 'category_misc_pos', 'category_personal_care', 'category_shopping_net', 'category_shopping_pos', 'category_travel', 'gender_M']
# **Correlation Matrix (filtered for correlation above 0.5):**

# %% [markdown]
# Show outliers
# ---

# %%
get_zscore(normal, 'amt')
print('\n')
plt.title('Distribution for purchase amounts')
ax1 = sns.distplot(normal['amt'],bins=10)
print('\n Show tukey \n')
get_tukey(normal, 'amt')
# Out:
# The score threshold is: 1
# The indices of the outliers:
# (array([   100,    133,    167, ..., 553484, 553492, 553502]),)
# Number of outliers is: 18103
# The score threshold is: 2
# The indices of the outliers:
# (array([   133,    167,    405, ..., 553378, 553492, 553502]),)
# Number of outliers is: 8237
# The score threshold is: 3
# The indices of the outliers:
# (array([   133,    167,    428, ..., 553084, 553350, 553492]),)
# Number of outliers is: 4406
# The score threshold is: 4
# The indices of the outliers:
# (array([   167,    428,    720, ..., 553084, 553350, 553492]),)
# Number of outliers is: 2520
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
#  Show tukey
# {1.0: [-63.42000000000001, 155.64000000000001, 40381],
#  1.5: [-99.93000000000002, 192.15000000000003, 26498],
#  2.0: [-136.44000000000003, 228.66000000000003, 16488],
#  2.5: [-172.95000000000002, 265.17, 12693],
#  3.0: [-209.46000000000004, 301.68000000000006, 10678],
#  3.5: [-245.97000000000006, 338.19000000000005, 9234],
#  4.0: [-282.48, 374.70000000000005, 8182],
#  4.5: [-318.99, 411.21000000000004, 7349],
#  5.0: [-355.5, 447.72, 6467]}

# %% [markdown]
# <h2>This shows that the distribution is negatively skewed very strongly, let's take a closer look.</h2>

# %% [markdown]
# <h2>Shows fraudulent outliers in the 'amount' column.</h2>

# %%
#This checks if we have outliers in our fraud cases
print(fraud_true['amt'].describe())
print('\n')
print(grubbs_test(fraud_true['amt']))

#This prints the distribution of the 'AMT' column
Box_plots(fraud_true['amt'])
# Out:
# count   2145.00
# mean     528.36
# std      392.75
# min        1.78
# 25%      214.51
# 50%      371.94
# 75%      907.77
# max     1320.92
# Name: amt, dtype: float64
#
#
# Grubbs Calculated Value: 2.0184676612318446
# Grubbs Critical Value: 4.2222424903417055
# From grubbs_test we observe that calculated value is lesser than critical value, Accept null hypothesis and conclude that there is no outliers
#
# None
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#This shows the z score for the normal purchases
get_zscore(normal, 'amt')
print('\n This shows the non-fraudulent purchases.')
# Out:
# The score threshold is: 1
# The indices of the outliers:
# (array([   100,    133,    167, ..., 553484, 553492, 553502]),)
# Number of outliers is: 18103
# The score threshold is: 2
# The indices of the outliers:
# (array([   133,    167,    405, ..., 553378, 553492, 553502]),)
# Number of outliers is: 8237
# The score threshold is: 3
# The indices of the outliers:
# (array([   133,    167,    428, ..., 553084, 553350, 553492]),)
# Number of outliers is: 4406
# The score threshold is: 4
# The indices of the outliers:
# (array([   167,    428,    720, ..., 553084, 553350, 553492]),)
# Number of outliers is: 2520
#
#  This shows the non-fraudulent purchases.

# %% [markdown]
# <h2>Shows normal transaction outliers in the 'amount' column.</h2>

# %%
#This checks if we have outliers in our normal purchases
print(normal_true['amt'].describe())
print('\n')
print(grubbs_test(normal_true['amt']))

#This prints the distribution of the 'AMT' column
Box_plots(normal_true['amt'])
# Out:
# count   553574.00
# mean        67.61
# std        152.47
# min          1.00
# 25%          9.60
# 50%         47.15
# 75%         82.62
# max      22768.11
# Name: amt, dtype: float64
#
#
# Grubbs Calculated Value: 148.8832468768014
# Grubbs Critical Value: 5.345123639735664
# From grubbs_test we observe that calculated value is greater than critical value, Reject null hypothesis and conclude that there is an outliers
#
# None
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#This shows the z score for the fraudulent purchases
get_zscore(fraud_true, 'amt')
print('\n This shows the fraudulent purchases.')
# Out:
# The score threshold is: 1
# The indices of the outliers:
# (array([   3,    6,    7,    8,    9,   17,   30,   34,   37,   39,   48,
#          50,   51,   52,   62,   64,   68,   69,   70,   72,   74,   80,
#          92,   94,   99,  110,  116,  117,  120,  125,  126,  133,  144,
#         147,  150,  195,  198,  204,  208,  212,  213,  221,  227,  234,
#         237,  239,  240,  242,  251,  253,  254,  255,  256,  261,  262,
#         264,  269,  276,  277,  279,  280,  283,  288,  289,  291,  299,
#         302,  303,  306,  315,  323,  324,  326,  336,  341,  343,  345,
#         346,  349,  355,  358,  378,  380,  387,  390,  393,  397,  403,
#         404,  406,  417,  418,  419,  427,  429,  435,  439,  440,  441,
#         450,  452,  453,  455,  456,  458,  459,  460,  461,  468,  477,
#         485,  493,  494,  495,  527,  530,  534,  541,  542,  543,  546,
#         573,  574,  580,  588,  592,  597,  605,  621,  623,  636,  640,
#         641,  642,  646,  647,  648,  651,  663,  664,  667,  670,  671,
#         674,  689,  693,  697,  698,  707,  718,  721,  726,  728,  729,
#         731,  732,  733,  744,  745,  752,  758,  759,  760,  761,  768,
#         778,  789,  798,  802,  804,  812,  822,  823,  824,  828,  836,
#         842,  843,  847,  852,  856,  857,  858,  861,  862,  867,  875,
#         876,  878,  879,  880,  886,  893,  896,  906,  909,  910,  911,
#         912,  915,  916,  929,  930,  933,  935,  937,  940,  942,  952,
#         955,  957,  963,  964,  972,  975,  981,  984,  987,  988,  990,
#         994,  996,  997,  998,  999, 1005, 1008, 1009, 1013, 1014, 1018,
#        1019, 1022, 1028, 1030, 1032, 1035, 1036, 1038, 1040, 1047, 1048,
#        1063, 1064, 1065, 1069, 1070, 1073, 1085, 1087, 1088, 1091, 1101,
#        1103, 1106, 1109, 1111, 1114, 1120, 1123, 1124, 1126, 1147, 1150,
#        1153, 1163, 1166, 1168, 1172, 1173, 1177, 1183, 1185, 1186, 1187,
#        1189, 1190, 1192, 1196, 1199, 1203, 1204, 1208, 1209, 1211, 1213,
#        1216, 1225, 1226, 1230, 1235, 1243, 1248, 1251, 1252, 1258, 1259,
#        1269, 1270, 1272, 1274, 1284, 1286, 1288, 1289, 1291, 1300, 1302,
#        1310, 1317, 1318, 1319, 1327, 1328, 1331, 1333, 1335, 1345, 1346,
#        1348, 1351, 1356, 1364, 1368, 1369, 1376, 1383, 1398, 1418, 1428,
#        1429, 1445, 1447, 1453, 1465, 1466, 1473, 1478, 1481, 1485, 1488,
#        1490, 1493, 1502, 1506, 1507, 1508, 1511, 1512, 1515, 1516, 1517,
#        1531, 1535, 1537, 1539, 1541, 1545, 1549, 1552, 1554, 1557, 1558,
#        1559, 1563, 1564, 1588, 1589, 1592, 1600, 1606, 1611, 1617, 1631,
#        1632, 1634, 1643, 1655, 1660, 1661, 1663, 1668, 1674, 1676, 1677,
#        1680, 1686, 1687, 1692, 1694, 1696, 1698, 1710, 1718, 1719, 1720,
#        1724, 1745, 1746, 1747, 1748, 1749, 1750, 1761, 1776, 1778, 1779,
#        1782, 1783, 1786, 1787, 1796, 1797, 1803, 1804, 1805, 1808, 1817,
#        1819, 1820, 1822, 1823, 1825, 1841, 1844, 1845, 1850, 1852, 1854,
#        1855, 1865, 1869, 1874, 1875, 1876, 1884, 1895, 1896, 1903, 1905,
#        1906, 1907, 1909, 1910, 1911, 1912, 1913, 1920, 1925, 1928, 1933,
#        1935, 1945, 1952, 1957, 1967, 1984, 1985, 1986, 1990, 1992, 1993,
#        2001, 2005, 2008, 2011, 2024, 2036, 2045, 2058, 2059, 2070, 2074,
#        2075, 2081, 2082, 2088, 2095, 2097, 2099, 2100, 2105, 2106, 2110,
#        2116, 2121, 2122, 2137, 2139, 2140, 2142]),)
# Number of outliers is: 491
# The score threshold is: 2
# The indices of the outliers:
# (array([ 693, 1208, 1903]),)
# Number of outliers is: 3
# The score threshold is: 3
# The indices of the outliers:
# (array([], dtype=int64),)
# Number of outliers is: 0
# The score threshold is: 4
# The indices of the outliers:
# (array([], dtype=int64),)
# Number of outliers is: 0
#
#  This shows the fraudulent purchases.

# %% [markdown]
# #Scale the features

# %%
from sklearn import preprocessing
from scipy.stats import skew, boxcox

# %% [markdown]
# #Train/Test Split

# %% [markdown]
# #Undersampling data to train the model
#
# ###This will create a 10 to 1 ratio of Normal to Fraud transactions for modeling

# %%
# Class count
count_class_0, count_class_1 = fraud.is_fraud.value_counts()

# Divide by class
df_class_0 = fraud[fraud['is_fraud'] == 0]
df_class_1 = fraud[fraud['is_fraud'] == 1]

df_class_0_under = df_class_0.sample(count_class_1*5)
df_under = pd.concat([df_class_0_under, df_class_1], axis=0)

print('Random under-sampling :')
print(df_under.is_fraud.value_counts())
# Out:
# Random under-sampling :
# 0    48255
# 1     9651
# Name: is_fraud, dtype: int64

# %%
df_under.is_fraud.value_counts().plot(kind='bar', title='Count (is_fraud)');

# %%
#This will delete the first column which is just a row counter
#df_under.drop(columns=['Unnamed: 0'],axis=1,inplace=True)
#df_under.columns

# %%
len_after = len(df_under)
len_before = len(fraud)
len_difference = len(fraud) - len(df_under)
print('**We reduced our data size from {} transactions by {} transactions to {} transactions for our training data.**'.format(len_before, len_difference, len_after))
# Out:
# **We reduced our data size from 1852394 transactions by 1794488 transactions to 57906 transactions for our training data.**

# %% [markdown]
# ###**We reduced our data size from 1852394 transactions by 1794488 transactions to 57906 transactions for our training data.**

# %% [markdown]
# ### Feature Engineering
#
# ####*create customer age feature*

# %%
df_under.head(1)
# Out:
#         trans_date_trans_time            cc_num  ... category_travel gender_M
# 1271963   2020-06-12 14:50:00  3541160328600277  ...               0        1
#
# [1 rows x 31 columns]

# %%
df_under['trans_date_trans_time'] = pd.to_datetime(df_under['trans_date_trans_time'])
df_under['unix_time'] = pd.to_datetime(df_under['unix_time'])
df_under['dob'] = pd.to_datetime(df_under['dob'])

# %%
df_under['cust_age'] = df_under['trans_date_trans_time'].dt.year - df_under['dob'].dt.year

# %%
#This will show us all of the fraudulent transactions and the number of times they have occured by age group.

plt.figure(figsize=[40,15])
ax = df_under.groupby(['cust_age', 'is_fraud']).size().plot(kind='bar')
ax.set_title("# of transaction which are the actual based on age")
ax.set_xlabel("(Age, is_fraud)")
ax.set_ylabel("Count of transaction")
for p in ax.patches:
    ax.annotate(str(format(int(p.get_height()), ',d')), (p.get_x(), p.get_height()*1.01))

# %% [markdown]
# <h2>We can see two large groups that have high amounts of fraudulent transactions on their account are ages (28-35) and (41-48).</h2>

# %%
df_under.drop(['cc_num', 'merchant', 'zip',
              'dob', 'trans_num',], axis=1, inplace=True)
df_under.reset_index(drop=True, inplace=True)

# %%
df_under.to_csv('unskewed_data.csv')

# %%
df_under.columns
# Out:
# Index(['trans_date_trans_time', 'category', 'amt', 'gender', 'lat', 'long',
#        'city_pop', 'job', 'unix_time', 'merch_lat', 'merch_long', 'is_fraud',
#        'category_food_dining', 'category_gas_transport',
#        'category_grocery_net', 'category_grocery_pos',
#        'category_health_fitness', 'category_home', 'category_kids_pets',
#        'category_misc_net', 'category_misc_pos', 'category_personal_care',
#        'category_shopping_net', 'category_shopping_pos', 'category_travel',
#        'gender_M', 'cust_age'],
#       dtype='object')

# %% [markdown]
# ### Feature & Target Split

# %%
feat_list = ['category', 'amt', 'gender', 'city_pop', 'cust_age', 'job']
feat_data = df_under[feat_list]
targ_list = ['is_fraud']
targ_data = df_under[targ_list]

# %% [markdown]
# ### Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
#create the specs for the column transformer
from sklearn.preprocessing import MinMaxScaler
#categories="auto" and drop="first" tell the encoder to create k-1 columns, rather than k columns
# and that the first category will be the implicit category
preprocess = make_column_transformer(
    (MinMaxScaler(), ['amt', 'city_pop', 'cust_age']),
    (OneHotEncoder(categories="auto",drop="first"),  ['category', 'gender', 'job'])
)

#fit_transform is the function that fits the transformations to the data and then does the transformation
X = preprocess.fit_transform(feat_data)

# scale target dataset
y = np.array(targ_data)

# %%
X.shape
# Out:
# (57906, 513)

# %% [markdown]
# ### Train Test Split

# %%
# train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, random_state=32)

# %% [markdown]
# ### Parameter Tuning Function

# %%
# a function to define the gridsearch inorder to get the best fit model with optimized parameters
# function return the best fit optimized model
# set K Fold as 20 for cross validation
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
from sklearn.model_selection import GridSearchCV

def gridsearchfn(X_train_data, X_test_data, y_train_data, y_test_data, 
                       model, param_grid, cv=10, scoring_fit='accuracy'):
    gs = GridSearchCV(
        estimator=model,
        param_grid=param_grid, 
        cv=cv, 
        n_jobs=-1, 
        scoring=scoring_fit,
        verbose=2
    )
    fitted_model = gs.fit(X_train_data, y_train_data)
    
    return fitted_model

# %% [markdown]
# ### Classification

# %%
acc_normal = []
acc_bagged = []

# %% [markdown]
# #### Support Vector Machine (Normal with Parameter Tuning using GridSearch CV)

# %%
from sklearn.svm import SVC
# define Support Vector Machine classifier with random state as 0 as model. 
model = SVC(random_state=32)

# parameter grid is defined inorder to search through and get the best fit parameters
param_grid = {
    'kernel' : ['linear', 'poly', 'rbf', 'sigmoid']
}

# invoke the gridsearch function to get the best fit model and parameters
model = gridsearchfn(X_train, X_test, y_train, y_test, model, param_grid)

print('Best Parameters : ', model.best_params_)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 16.8min
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed: 17.7min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Best Parameters :  {'kernel': 'rbf'}

# %%
# Best Parameters :  {'kernel': 'rbf'}
svc_clf = SVC(kernel = 'rbf', random_state=32, probability=True)
svc_clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=True, random_state=32, shrinking=True, tol=0.001,
#     verbose=False)

# %%
svc_clf.score(X_train, y_train)
# Out:
# 0.9234734644431271

# %%
acc_normal.append(svc_clf.score(X_test, y_test))
svc_clf.score(X_test, y_test)
# Out:
# 0.9157988382437595

# %%
#suppress exponential notation, define an appropriate float formatter

# plot the confusion matrix
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(svc_clf, X_test, y_test, values_format='d')

# %% [markdown]
# #### Support Vector Machine (Bagged with Parameter Tuned Configuration)

# %%
from sklearn.ensemble import BaggingClassifier

svc_bagged = BaggingClassifier(base_estimator=SVC(kernel='rbf'),
                        n_estimators=10, random_state=32)
svc_bagged_clf = svc_bagged.fit(X_train, y_train.ravel())

# %%
svc_bagged_clf.score(X_train, y_train)
# Out:
# 0.9244013712400443

# %%
acc_bagged.append(svc_bagged_clf.score(X_test, y_test))
svc_bagged_clf.score(X_test, y_test)
# Out:
# 0.9172641163849495

# %%
cross_val_score(svc_bagged_clf, X_test, y_test, cv=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.91313448, 0.90947148, 0.90894819, 0.90685505, 0.91732077,
#        0.90947148, 0.90790162, 0.91522763, 0.90999477, 0.91937173])

# %%
pd.reset_option('display.float_format')
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(svc_bagged_clf, X_test, y_test, values_format='d')

# %% [markdown]
# #### Random Forest (Normal with Parameter Tuning using GridSearch CV)

# %%
# define xgboost classifier with random state as 0 as model. 
model = RandomForestClassifier(random_state=32)

# parameter grid is defined inorder to search through and get the best fit parameters
param_grid = {
    'n_estimators': [20,40,60],
    'criterion' : ['gini', 'entropy']
}

# invoke the gridsearch function to get the best fit model and parameters
model = gridsearchfn(X_train, X_test, y_train, y_test, model, param_grid)

print('Best Parameters : ', model.best_params_)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  4.0min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:739: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# Best Parameters :  {'criterion': 'entropy', 'n_estimators': 60}

# %%
# Best Parameters :  {'criterion': 'entropy', 'n_estimators': 60}
rndf_clf = RandomForestClassifier(criterion = 'gini', n_estimators= 60, random_state=32)
rndf_clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=60,
#                        n_jobs=None, oob_score=False, random_state=32, verbose=0,
#                        warm_start=False)

# %%
rndf_clf.score(X_train, y_train)
# Out:
# 0.9999742248111967

# %%
acc_normal.append(rndf_clf.score(X_test, y_test))
rndf_clf.score(X_test, y_test)
# Out:
# 0.9731540111989115

# %%
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(rndf_clf, X_test, y_test, values_format='d')

# %% [markdown]
# #### Random Forest (Bagged with Parameter Tuned Configuration)

# %%
rndf_bagged = BaggingClassifier(base_estimator=RandomForestClassifier(criterion = 'entropy', n_estimators= 60, random_state=32),
                        n_estimators=10, random_state=32)
rndf_bagged_clf = rndf_bagged.fit(X_train, y_train.ravel())

# %%
rndf_bagged_clf.score(X_train, y_train)
# Out:
# 0.991597288450138

# %%
acc_bagged.append(rndf_bagged_clf.score(X_test, y_test))
rndf_bagged_clf.score(X_test, y_test)
# Out:
# 0.9726830289392433

# %%
pd.reset_option('display.float_format')
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(rndf_bagged_clf, X_test, y_test, values_format='d')

# %%
cross_val_score(rndf_bagged_clf, X_test, y_test, cv=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.97069597, 0.96807954, 0.96441654, 0.96703297, 0.97069597,
#        0.96703297, 0.96650968, 0.9696494 , 0.97174254, 0.96701571])

# %% [markdown]
# #### K-Nearest Neighbours (Normal with Parameter Tuning using GridSearch CV)

# %%
# define xgboost classifier with random state as 0 as model. 
model = KNeighborsClassifier()

# parameter grid is defined inorder to search through and get the best fit parameters
param_grid = {
    'n_neighbors': [5,10,15],
    'weights' : ['uniform', 'distance']
    
}

# invoke the gridsearch function to get the best fit model and parameters
model = gridsearchfn(X_train, X_test, y_train, y_test, model, param_grid)

print('Best Parameters : ', model.best_params_)
# Out:
# Fitting 10 folds for each of 6 candidates, totalling 60 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed:  2.3min
# Best Parameters :  {'n_neighbors': 15, 'weights': 'distance'}
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:  3.5min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:739: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)

# %%
# Best Parameters :  {'n_neighbors': 15, 'weights': 'distance'}
knn_clf = KNeighborsClassifier(n_neighbors = 15, weights = 'distance')
knn_clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=15, p=2,
#                      weights='distance')

# %%
knn_clf.score(X_train, y_train)
# Out:
# 1.0

# %%
acc_normal.append(knn_clf.score(X_test, y_test))
knn_clf.score(X_test, y_test)
# Out:
# 0.9061175362394683

# %%
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(knn_clf, X_test, y_test, values_format='d')

# %% [markdown]
# #### K-Nearest Neighbours (Bagged with Parameter Tuned Configuration)

# %%
knn_bagged = BaggingClassifier(base_estimator=KNeighborsClassifier(n_neighbors = 15, weights = 'distance'),
                        n_estimators=10, random_state=32)
knn_bagged_clf = knn_bagged.fit(X_train, y_train.ravel())

# %%
knn_bagged_clf.score(X_train, y_train)
# Out:
# 0.9920870170373998

# %%
acc_bagged.append(knn_bagged_clf.score(X_test, y_test))
knn_bagged_clf.score(X_test, y_test)
# Out:
# 0.8997331100528547

# %%
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(knn_bagged_clf, X_test, y_test, values_format='d')

# %%
cross_val_score(knn_bagged_clf, X_test, y_test, cv=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.88697017, 0.87859759, 0.87755102, 0.8822606 , 0.89429618,
#        0.88697017, 0.88540031, 0.88906332, 0.88278388, 0.88272251])

# %% [markdown]
# #### Ridge (Normal with Parameter Tuning using GridSearch CV)

# %%
from sklearn.linear_model import RidgeClassifier

model = RidgeClassifier(random_state=32)

# parameter grid is defined inorder to search through and get the best fit parameters
param_grid = {
    'alpha': [0.5,1.5,2, 2.5]
}

# invoke the gridsearch function to get the best fit model and parameters
model = gridsearchfn(X_train, X_test, y_train, y_test, model, param_grid)

print('Best Parameters : ', model.best_params_)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# Best Parameters :  {'alpha': 0.5}
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:    3.0s finished
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:940: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Best Parameters :  {'alpha': 0.5}
rid_clf = RidgeClassifier(alpha = 0.5, random_state=32)
rid_clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/_ridge.py:940: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RidgeClassifier(alpha=0.5, class_weight=None, copy_X=True, fit_intercept=True,
#                 max_iter=None, normalize=False, random_state=32, solver='auto',
#                 tol=0.001)

# %%
rid_clf.score(X_train, y_train)
# Out:
# 0.9169265664870995

# %%
acc_normal.append(rid_clf.score(X_test, y_test))
rid_clf.score(X_test, y_test)
# Out:
# 0.9153278559840913

# %%
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(rid_clf, X_test, y_test, values_format='d')

# %% [markdown]
# #### Ridge (Bagged with Parameter Tuned Configuration)

# %%
rid_bagged = BaggingClassifier(base_estimator=RidgeClassifier(alpha = 0.5, random_state=32),
                        n_estimators=10, random_state=32)
rid_bagged_clf = rid_bagged.fit(X_train, y_train.ravel())

# %%
rid_bagged_clf.score(X_train, y_train)
# Out:
# 0.9162306363894116

# %%
acc_bagged.append(rid_bagged_clf.score(X_test, y_test))
rid_bagged_clf.score(X_test, y_test)
# Out:
# 0.9141242346538281

# %%
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(rid_bagged_clf, X_test, y_test, values_format='d')

# %%
cross_val_score(rndf_bagged_clf, X_test, y_test, cv=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.97069597, 0.96807954, 0.96441654, 0.96703297, 0.97069597,
#        0.96703297, 0.96650968, 0.9696494 , 0.97174254, 0.96701571])

# %% [markdown]
# #### Extra Tree (Normal with Parameter Tuning using GridSearch CV)

# %%
from sklearn.ensemble import ExtraTreesClassifier

model = ExtraTreesClassifier(random_state=32)

# parameter grid is defined inorder to search through and get the best fit parameters
param_grid = {
    'n_estimators': [100,150,200, 250]
}

# invoke the gridsearch function to get the best fit model and parameters
model = gridsearchfn(X_train, X_test, y_train, y_test, model, param_grid)

print('Best Parameters : ', model.best_params_)
# Out:
# Fitting 10 folds for each of 4 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# /usr/local/lib/python3.6/dist-packages/joblib/externals/loky/process_executor.py:691: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 22.5min
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed: 24.4min finished
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py:739: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   self.best_estimator_.fit(X, y, **fit_params)
# Best Parameters :  {'n_estimators': 250}

# %%
# Best Parameters :  {'n_estimators': 250}
extr_clf = ExtraTreesClassifier(n_estimators = 250, random_state=32)
extr_clf.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=250,
#                      n_jobs=None, oob_score=False, random_state=32, verbose=0,
#                      warm_start=False)

# %%
extr_clf.score(X_train, y_train)
# Out:
# 1.0

# %%
acc_normal.append(extr_clf.score(X_test, y_test))
extr_clf.score(X_test, y_test)
# Out:
# 0.9588152179601235

# %%
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(extr_clf, X_test, y_test, values_format='d')

# %% [markdown]
# #### Extra Tree (Bagged with Parameter Tuned Configuration)

# %%
extr_bagged = BaggingClassifier(base_estimator=ExtraTreesClassifier(n_estimators = 250, random_state=32),
                        n_estimators=10, random_state=32)
extr_bagged_clf = extr_bagged.fit(X_train, y_train.ravel())

# %%
extr_bagged_clf.score(X_train, y_train)
# Out:
# 0.9974224811196742

# %%
acc_bagged.append(extr_bagged_clf.score(X_test, y_test))
extr_bagged_clf.score(X_test, y_test)
# Out:
# 0.9653043068711079

# %%
plt.rcParams["figure.figsize"] = (5,5)
plot_confusion_matrix(extr_bagged_clf, X_test, y_test, values_format='d')

# %%
cross_val_score(extr_bagged_clf, X_test, y_test, cv=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.6/dist-packages/sklearn/ensemble/_bagging.py:645: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([0.96232339, 0.95761381, 0.95761381, 0.95970696, 0.96807954,
#        0.95395081, 0.9544741 , 0.96232339, 0.96127682, 0.96073298])

# %% [markdown]
# ### Classifier Accuracy

# %%
import matplotlib.pyplot as plt
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams['figure.figsize'] = (12, 10)

clf_acc_df = pd.DataFrame([acc_normal,acc_bagged]).T

clf_acc_df.index = ['SVC', 'Random Forest', 'KNN', 'Ridge', 'Extra Tree']
clf_acc_df.columns = ['Normal', 'Bagged']
clf_acc_df = 100 * clf_acc_df

clf_acc_df.plot.bar()
plt.title('Accuarcy of Classifiers')
# Out:
# Text(0.5, 1.0, 'Accuarcy of Classifiers')

# %% [markdown]
# ### ROC Curve - Normal Models

# %%
from sklearn.metrics import roc_auc_score, roc_curve

#Plot the SVC normal model Roc curve
y_pred_proba = svc_clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="SVC Normal, auc="+str(auc))

#Plot the Random Forest normal model Roc curve
y_pred_proba =rndf_clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="Random Forest Normal, auc="+str(auc))

#Plot the KNN normal model Roc curve
y_pred_proba =knn_clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="KNN Normal, auc="+str(auc))

# ridge classifier cannot be plotted since it doesn't have probability function
#y_pred_proba =rid_clf.predict_proba(X_test)[::,1]
#fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
#auc = roc_auc_score(y_test, y_pred_proba)
#plt.plot(fpr,tpr,label="Ridge Normal, auc="+str(auc))

#Plot the Extra Tree normal model Roc curve
y_pred_proba = extr_clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="Extra Tree Normal, auc="+str(auc))

#Plot the legend and print
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ### ROC Curve - Bagged Models

# %%
#Plot the SVC bagged model Roc curve
y_pred_proba = svc_bagged_clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="SVC Bagged, auc="+str(auc))

#Plot the Random Forest bagged model Roc curve
y_pred_proba =rndf_bagged_clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="Random Forest Bagged, auc="+str(auc))

#Plot the KNN bagged model Roc curve
y_pred_proba =knn_bagged_clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="KNN Bagged, auc="+str(auc))

#Plot the Ridge regression bagged model Roc curve
y_pred_proba =rid_bagged_clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="Ridge Bagged, auc="+str(auc))

#Plot the Extra Tree bagged model Roc curve
y_pred_proba = extr_bagged_clf.predict_proba(X_test)[::,1]
fpr, tpr, _ = roc_curve(y_test,  y_pred_proba)
auc = roc_auc_score(y_test, y_pred_proba)
plt.plot(fpr,tpr,label="Extra Tree Bagged, auc="+str(auc))

#Show legend and show plot
plt.legend(loc=4)
plt.show()

# %% [markdown]
# ### Deep Learning Neural Network for Imbalanced Data

# %%
# train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, shuffle=True, random_state=32)
X_test, X_val, y_test, y_val = train_test_split(X, y, test_size=0.55, shuffle=True, random_state=32)

# %%
#Show metrics from tensorflow
import tensorflow.keras as keras
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
]

def make_model(metrics = METRICS, output_bias=None):
  if output_bias is not None:
    output_bias = tf.keras.initializers.Constant(output_bias)
  model = keras.Sequential([
      keras.layers.Dense(
          16, activation='relu',
          input_shape=(X_train.shape[-1],)),
      keras.layers.Dropout(0.5),
      keras.layers.Dense(1, activation='sigmoid',
                         bias_initializer=output_bias),
  ])

  model.compile(
      optimizer=keras.optimizers.Adam(lr=1e-3),
      loss=keras.losses.BinaryCrossentropy(),
      metrics=metrics)

  return model

# %%
EPOCHS = 100
BATCH_SIZE = 32

early_stopping = keras.callbacks.EarlyStopping(
    monitor='val_auc', 
    verbose=1,
    patience=10,
    mode='max', 
    restore_best_weights=True)

# %%
model = make_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                8224
# _________________________________________________________________
# dropout (Dropout)            (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 8,241
# Trainable params: 8,241
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = model.fit(
    X_train,
    y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks = [early_stopping],
    validation_data=(X_val, y_val))
# Out:
# Epoch 1/100
# 1213/1213 [==============================] - 4s 4ms/step - loss: 0.4349 - tp: 490.0000 - fp: 730.0000 - tn: 31584.0000 - fn: 5993.0000 - accuracy: 0.8267 - precision: 0.4016 - recall: 0.0756 - auc: 0.6838 - val_loss: 0.3556 - val_tp: 645.0000 - val_fp: 28.0000 - val_tn: 26495.0000 - val_fn: 4681.0000 - val_accuracy: 0.8521 - val_precision: 0.9584 - val_recall: 0.1211 - val_auc: 0.8140
# Epoch 2/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.3467 - tp: 2059.0000 - fp: 211.0000 - tn: 32103.0000 - fn: 4424.0000 - accuracy: 0.8805 - precision: 0.9070 - recall: 0.3176 - auc: 0.8138 - val_loss: 0.2976 - val_tp: 2461.0000 - val_fp: 125.0000 - val_tn: 26398.0000 - val_fn: 2865.0000 - val_accuracy: 0.9061 - val_precision: 0.9517 - val_recall: 0.4621 - val_auc: 0.8518
# Epoch 3/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2964 - tp: 3127.0000 - fp: 284.0000 - tn: 32030.0000 - fn: 3356.0000 - accuracy: 0.9062 - precision: 0.9167 - recall: 0.4823 - auc: 0.8563 - val_loss: 0.2577 - val_tp: 3056.0000 - val_fp: 173.0000 - val_tn: 26350.0000 - val_fn: 2270.0000 - val_accuracy: 0.9233 - val_precision: 0.9464 - val_recall: 0.5738 - val_auc: 0.8833
# Epoch 4/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2677 - tp: 3615.0000 - fp: 288.0000 - tn: 32026.0000 - fn: 2868.0000 - accuracy: 0.9187 - precision: 0.9262 - recall: 0.5576 - auc: 0.8802 - val_loss: 0.2358 - val_tp: 3088.0000 - val_fp: 146.0000 - val_tn: 26377.0000 - val_fn: 2238.0000 - val_accuracy: 0.9251 - val_precision: 0.9549 - val_recall: 0.5798 - val_auc: 0.9083
# Epoch 5/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2506 - tp: 3785.0000 - fp: 258.0000 - tn: 32056.0000 - fn: 2698.0000 - accuracy: 0.9238 - precision: 0.9362 - recall: 0.5838 - auc: 0.8982 - val_loss: 0.2232 - val_tp: 3386.0000 - val_fp: 160.0000 - val_tn: 26363.0000 - val_fn: 1940.0000 - val_accuracy: 0.9341 - val_precision: 0.9549 - val_recall: 0.6357 - val_auc: 0.9176
# Epoch 6/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2382 - tp: 3904.0000 - fp: 258.0000 - tn: 32056.0000 - fn: 2579.0000 - accuracy: 0.9269 - precision: 0.9380 - recall: 0.6022 - auc: 0.9079 - val_loss: 0.2143 - val_tp: 3554.0000 - val_fp: 174.0000 - val_tn: 26349.0000 - val_fn: 1772.0000 - val_accuracy: 0.9389 - val_precision: 0.9533 - val_recall: 0.6673 - val_auc: 0.9227
# Epoch 7/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2298 - tp: 4033.0000 - fp: 268.0000 - tn: 32046.0000 - fn: 2450.0000 - accuracy: 0.9299 - precision: 0.9377 - recall: 0.6221 - auc: 0.9161 - val_loss: 0.2083 - val_tp: 3605.0000 - val_fp: 154.0000 - val_tn: 26369.0000 - val_fn: 1721.0000 - val_accuracy: 0.9411 - val_precision: 0.9590 - val_recall: 0.6769 - val_auc: 0.9264
# Epoch 8/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.2248 - tp: 4126.0000 - fp: 266.0000 - tn: 32048.0000 - fn: 2357.0000 - accuracy: 0.9324 - precision: 0.9394 - recall: 0.6364 - auc: 0.9210 - val_loss: 0.2043 - val_tp: 3616.0000 - val_fp: 152.0000 - val_tn: 26371.0000 - val_fn: 1710.0000 - val_accuracy: 0.9415 - val_precision: 0.9597 - val_recall: 0.6789 - val_auc: 0.9301
# Epoch 9/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.2196 - tp: 4130.0000 - fp: 280.0000 - tn: 32034.0000 - fn: 2353.0000 - accuracy: 0.9321 - precision: 0.9365 - recall: 0.6371 - auc: 0.9254 - val_loss: 0.1993 - val_tp: 3676.0000 - val_fp: 160.0000 - val_tn: 26363.0000 - val_fn: 1650.0000 - val_accuracy: 0.9432 - val_precision: 0.9583 - val_recall: 0.6902 - val_auc: 0.9336
# Epoch 10/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.2157 - tp: 4182.0000 - fp: 268.0000 - tn: 32046.0000 - fn: 2301.0000 - accuracy: 0.9338 - precision: 0.9398 - recall: 0.6451 - auc: 0.9294 - val_loss: 0.1954 - val_tp: 3733.0000 - val_fp: 161.0000 - val_tn: 26362.0000 - val_fn: 1593.0000 - val_accuracy: 0.9449 - val_precision: 0.9587 - val_recall: 0.7009 - val_auc: 0.9349
# Epoch 11/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2124 - tp: 4233.0000 - fp: 252.0000 - tn: 32062.0000 - fn: 2250.0000 - accuracy: 0.9355 - precision: 0.9438 - recall: 0.6529 - auc: 0.9302 - val_loss: 0.1932 - val_tp: 3718.0000 - val_fp: 143.0000 - val_tn: 26380.0000 - val_fn: 1608.0000 - val_accuracy: 0.9450 - val_precision: 0.9630 - val_recall: 0.6981 - val_auc: 0.9377
# Epoch 12/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2119 - tp: 4271.0000 - fp: 254.0000 - tn: 32060.0000 - fn: 2212.0000 - accuracy: 0.9364 - precision: 0.9439 - recall: 0.6588 - auc: 0.9335 - val_loss: 0.1918 - val_tp: 3663.0000 - val_fp: 144.0000 - val_tn: 26379.0000 - val_fn: 1663.0000 - val_accuracy: 0.9433 - val_precision: 0.9622 - val_recall: 0.6878 - val_auc: 0.9392
# Epoch 13/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2070 - tp: 4276.0000 - fp: 241.0000 - tn: 32073.0000 - fn: 2207.0000 - accuracy: 0.9369 - precision: 0.9466 - recall: 0.6596 - auc: 0.9360 - val_loss: 0.1884 - val_tp: 3768.0000 - val_fp: 157.0000 - val_tn: 26366.0000 - val_fn: 1558.0000 - val_accuracy: 0.9462 - val_precision: 0.9600 - val_recall: 0.7075 - val_auc: 0.9400
# Epoch 14/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2017 - tp: 4309.0000 - fp: 275.0000 - tn: 32039.0000 - fn: 2174.0000 - accuracy: 0.9369 - precision: 0.9400 - recall: 0.6647 - auc: 0.9385 - val_loss: 0.1879 - val_tp: 3698.0000 - val_fp: 139.0000 - val_tn: 26384.0000 - val_fn: 1628.0000 - val_accuracy: 0.9445 - val_precision: 0.9638 - val_recall: 0.6943 - val_auc: 0.9428
# Epoch 15/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2001 - tp: 4339.0000 - fp: 256.0000 - tn: 32058.0000 - fn: 2144.0000 - accuracy: 0.9381 - precision: 0.9443 - recall: 0.6693 - auc: 0.9394 - val_loss: 0.1853 - val_tp: 3828.0000 - val_fp: 173.0000 - val_tn: 26350.0000 - val_fn: 1498.0000 - val_accuracy: 0.9475 - val_precision: 0.9568 - val_recall: 0.7187 - val_auc: 0.9439
# Epoch 16/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.2000 - tp: 4330.0000 - fp: 256.0000 - tn: 32058.0000 - fn: 2153.0000 - accuracy: 0.9379 - precision: 0.9442 - recall: 0.6679 - auc: 0.9408 - val_loss: 0.1811 - val_tp: 3822.0000 - val_fp: 152.0000 - val_tn: 26371.0000 - val_fn: 1504.0000 - val_accuracy: 0.9480 - val_precision: 0.9618 - val_recall: 0.7176 - val_auc: 0.9457
# Epoch 17/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1981 - tp: 4345.0000 - fp: 268.0000 - tn: 32046.0000 - fn: 2138.0000 - accuracy: 0.9380 - precision: 0.9419 - recall: 0.6702 - auc: 0.9422 - val_loss: 0.1806 - val_tp: 3828.0000 - val_fp: 156.0000 - val_tn: 26367.0000 - val_fn: 1498.0000 - val_accuracy: 0.9481 - val_precision: 0.9608 - val_recall: 0.7187 - val_auc: 0.9472
# Epoch 18/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1995 - tp: 4375.0000 - fp: 253.0000 - tn: 32061.0000 - fn: 2108.0000 - accuracy: 0.9391 - precision: 0.9453 - recall: 0.6748 - auc: 0.9421 - val_loss: 0.1784 - val_tp: 3814.0000 - val_fp: 149.0000 - val_tn: 26374.0000 - val_fn: 1512.0000 - val_accuracy: 0.9478 - val_precision: 0.9624 - val_recall: 0.7161 - val_auc: 0.9481
# Epoch 19/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1936 - tp: 4407.0000 - fp: 283.0000 - tn: 32031.0000 - fn: 2076.0000 - accuracy: 0.9392 - precision: 0.9397 - recall: 0.6798 - auc: 0.9444 - val_loss: 0.1759 - val_tp: 3850.0000 - val_fp: 155.0000 - val_tn: 26368.0000 - val_fn: 1476.0000 - val_accuracy: 0.9488 - val_precision: 0.9613 - val_recall: 0.7229 - val_auc: 0.9488
# Epoch 20/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1958 - tp: 4394.0000 - fp: 273.0000 - tn: 32041.0000 - fn: 2089.0000 - accuracy: 0.9391 - precision: 0.9415 - recall: 0.6778 - auc: 0.9448 - val_loss: 0.1753 - val_tp: 3830.0000 - val_fp: 148.0000 - val_tn: 26375.0000 - val_fn: 1496.0000 - val_accuracy: 0.9484 - val_precision: 0.9628 - val_recall: 0.7191 - val_auc: 0.9507
# Epoch 21/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1895 - tp: 4445.0000 - fp: 262.0000 - tn: 32052.0000 - fn: 2038.0000 - accuracy: 0.9407 - precision: 0.9443 - recall: 0.6856 - auc: 0.9462 - val_loss: 0.1726 - val_tp: 3875.0000 - val_fp: 161.0000 - val_tn: 26362.0000 - val_fn: 1451.0000 - val_accuracy: 0.9494 - val_precision: 0.9601 - val_recall: 0.7276 - val_auc: 0.9507
# Epoch 22/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1890 - tp: 4437.0000 - fp: 261.0000 - tn: 32053.0000 - fn: 2046.0000 - accuracy: 0.9405 - precision: 0.9444 - recall: 0.6844 - auc: 0.9478 - val_loss: 0.1719 - val_tp: 3865.0000 - val_fp: 148.0000 - val_tn: 26375.0000 - val_fn: 1461.0000 - val_accuracy: 0.9495 - val_precision: 0.9631 - val_recall: 0.7257 - val_auc: 0.9511
# Epoch 23/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1890 - tp: 4447.0000 - fp: 279.0000 - tn: 32035.0000 - fn: 2036.0000 - accuracy: 0.9403 - precision: 0.9410 - recall: 0.6859 - auc: 0.9477 - val_loss: 0.1712 - val_tp: 3849.0000 - val_fp: 143.0000 - val_tn: 26380.0000 - val_fn: 1477.0000 - val_accuracy: 0.9491 - val_precision: 0.9642 - val_recall: 0.7227 - val_auc: 0.9534
# Epoch 24/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1874 - tp: 4459.0000 - fp: 266.0000 - tn: 32048.0000 - fn: 2024.0000 - accuracy: 0.9410 - precision: 0.9437 - recall: 0.6878 - auc: 0.9490 - val_loss: 0.1694 - val_tp: 3896.0000 - val_fp: 157.0000 - val_tn: 26366.0000 - val_fn: 1430.0000 - val_accuracy: 0.9502 - val_precision: 0.9613 - val_recall: 0.7315 - val_auc: 0.9522
# Epoch 25/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1862 - tp: 4483.0000 - fp: 270.0000 - tn: 32044.0000 - fn: 2000.0000 - accuracy: 0.9415 - precision: 0.9432 - recall: 0.6915 - auc: 0.9496 - val_loss: 0.1693 - val_tp: 3872.0000 - val_fp: 140.0000 - val_tn: 26383.0000 - val_fn: 1454.0000 - val_accuracy: 0.9500 - val_precision: 0.9651 - val_recall: 0.7270 - val_auc: 0.9527
# Epoch 26/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1846 - tp: 4516.0000 - fp: 282.0000 - tn: 32032.0000 - fn: 1967.0000 - accuracy: 0.9420 - precision: 0.9412 - recall: 0.6966 - auc: 0.9507 - val_loss: 0.1683 - val_tp: 3873.0000 - val_fp: 149.0000 - val_tn: 26374.0000 - val_fn: 1453.0000 - val_accuracy: 0.9497 - val_precision: 0.9630 - val_recall: 0.7272 - val_auc: 0.9537
# Epoch 27/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1872 - tp: 4486.0000 - fp: 280.0000 - tn: 32034.0000 - fn: 1997.0000 - accuracy: 0.9413 - precision: 0.9413 - recall: 0.6920 - auc: 0.9497 - val_loss: 0.1683 - val_tp: 3845.0000 - val_fp: 136.0000 - val_tn: 26387.0000 - val_fn: 1481.0000 - val_accuracy: 0.9492 - val_precision: 0.9658 - val_recall: 0.7219 - val_auc: 0.9538
# Epoch 28/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1814 - tp: 4504.0000 - fp: 286.0000 - tn: 32028.0000 - fn: 1979.0000 - accuracy: 0.9416 - precision: 0.9403 - recall: 0.6947 - auc: 0.9507 - val_loss: 0.1681 - val_tp: 3842.0000 - val_fp: 138.0000 - val_tn: 26385.0000 - val_fn: 1484.0000 - val_accuracy: 0.9491 - val_precision: 0.9653 - val_recall: 0.7214 - val_auc: 0.9546
# Epoch 29/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1816 - tp: 4520.0000 - fp: 283.0000 - tn: 32031.0000 - fn: 1963.0000 - accuracy: 0.9421 - precision: 0.9411 - recall: 0.6972 - auc: 0.9519 - val_loss: 0.1681 - val_tp: 3850.0000 - val_fp: 137.0000 - val_tn: 26386.0000 - val_fn: 1476.0000 - val_accuracy: 0.9494 - val_precision: 0.9656 - val_recall: 0.7229 - val_auc: 0.9543
# Epoch 30/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1807 - tp: 4521.0000 - fp: 276.0000 - tn: 32038.0000 - fn: 1962.0000 - accuracy: 0.9423 - precision: 0.9425 - recall: 0.6974 - auc: 0.9512 - val_loss: 0.1665 - val_tp: 3888.0000 - val_fp: 144.0000 - val_tn: 26379.0000 - val_fn: 1438.0000 - val_accuracy: 0.9503 - val_precision: 0.9643 - val_recall: 0.7300 - val_auc: 0.9545
# Epoch 31/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1823 - tp: 4518.0000 - fp: 275.0000 - tn: 32039.0000 - fn: 1965.0000 - accuracy: 0.9423 - precision: 0.9426 - recall: 0.6969 - auc: 0.9521 - val_loss: 0.1657 - val_tp: 3867.0000 - val_fp: 144.0000 - val_tn: 26379.0000 - val_fn: 1459.0000 - val_accuracy: 0.9497 - val_precision: 0.9641 - val_recall: 0.7261 - val_auc: 0.9557
# Epoch 32/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1811 - tp: 4507.0000 - fp: 283.0000 - tn: 32031.0000 - fn: 1976.0000 - accuracy: 0.9418 - precision: 0.9409 - recall: 0.6952 - auc: 0.9527 - val_loss: 0.1648 - val_tp: 3871.0000 - val_fp: 144.0000 - val_tn: 26379.0000 - val_fn: 1455.0000 - val_accuracy: 0.9498 - val_precision: 0.9641 - val_recall: 0.7268 - val_auc: 0.9556
# Epoch 33/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1784 - tp: 4520.0000 - fp: 270.0000 - tn: 32044.0000 - fn: 1963.0000 - accuracy: 0.9424 - precision: 0.9436 - recall: 0.6972 - auc: 0.9531 - val_loss: 0.1634 - val_tp: 3914.0000 - val_fp: 163.0000 - val_tn: 26360.0000 - val_fn: 1412.0000 - val_accuracy: 0.9505 - val_precision: 0.9600 - val_recall: 0.7349 - val_auc: 0.9555
# Epoch 34/100
# 1213/1213 [==============================] - 4s 4ms/step - loss: 0.1784 - tp: 4559.0000 - fp: 280.0000 - tn: 32034.0000 - fn: 1924.0000 - accuracy: 0.9432 - precision: 0.9421 - recall: 0.7032 - auc: 0.9531 - val_loss: 0.1642 - val_tp: 3866.0000 - val_fp: 129.0000 - val_tn: 26394.0000 - val_fn: 1460.0000 - val_accuracy: 0.9501 - val_precision: 0.9677 - val_recall: 0.7259 - val_auc: 0.9559
# Epoch 35/100
# 1213/1213 [==============================] - 5s 4ms/step - loss: 0.1798 - tp: 4523.0000 - fp: 278.0000 - tn: 32036.0000 - fn: 1960.0000 - accuracy: 0.9423 - precision: 0.9421 - recall: 0.6977 - auc: 0.9534 - val_loss: 0.1638 - val_tp: 3898.0000 - val_fp: 153.0000 - val_tn: 26370.0000 - val_fn: 1428.0000 - val_accuracy: 0.9504 - val_precision: 0.9622 - val_recall: 0.7319 - val_auc: 0.9543
# Epoch 36/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1776 - tp: 4525.0000 - fp: 306.0000 - tn: 32008.0000 - fn: 1958.0000 - accuracy: 0.9416 - precision: 0.9367 - recall: 0.6980 - auc: 0.9546 - val_loss: 0.1646 - val_tp: 3878.0000 - val_fp: 137.0000 - val_tn: 26386.0000 - val_fn: 1448.0000 - val_accuracy: 0.9502 - val_precision: 0.9659 - val_recall: 0.7281 - val_auc: 0.9557
# Epoch 37/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1762 - tp: 4544.0000 - fp: 278.0000 - tn: 32036.0000 - fn: 1939.0000 - accuracy: 0.9429 - precision: 0.9423 - recall: 0.7009 - auc: 0.9544 - val_loss: 0.1633 - val_tp: 3878.0000 - val_fp: 143.0000 - val_tn: 26380.0000 - val_fn: 1448.0000 - val_accuracy: 0.9500 - val_precision: 0.9644 - val_recall: 0.7281 - val_auc: 0.9570
# Epoch 38/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1758 - tp: 4570.0000 - fp: 277.0000 - tn: 32037.0000 - fn: 1913.0000 - accuracy: 0.9436 - precision: 0.9429 - recall: 0.7049 - auc: 0.9539 - val_loss: 0.1627 - val_tp: 3901.0000 - val_fp: 152.0000 - val_tn: 26371.0000 - val_fn: 1425.0000 - val_accuracy: 0.9505 - val_precision: 0.9625 - val_recall: 0.7324 - val_auc: 0.9569
# Epoch 39/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1786 - tp: 4515.0000 - fp: 296.0000 - tn: 32018.0000 - fn: 1968.0000 - accuracy: 0.9416 - precision: 0.9385 - recall: 0.6964 - auc: 0.9543 - val_loss: 0.1608 - val_tp: 3931.0000 - val_fp: 156.0000 - val_tn: 26367.0000 - val_fn: 1395.0000 - val_accuracy: 0.9513 - val_precision: 0.9618 - val_recall: 0.7381 - val_auc: 0.9569
# Epoch 40/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1771 - tp: 4547.0000 - fp: 295.0000 - tn: 32019.0000 - fn: 1936.0000 - accuracy: 0.9425 - precision: 0.9391 - recall: 0.7014 - auc: 0.9540 - val_loss: 0.1618 - val_tp: 3903.0000 - val_fp: 152.0000 - val_tn: 26371.0000 - val_fn: 1423.0000 - val_accuracy: 0.9505 - val_precision: 0.9625 - val_recall: 0.7328 - val_auc: 0.9565
# Epoch 41/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1766 - tp: 4560.0000 - fp: 296.0000 - tn: 32018.0000 - fn: 1923.0000 - accuracy: 0.9428 - precision: 0.9390 - recall: 0.7034 - auc: 0.9546 - val_loss: 0.1609 - val_tp: 3918.0000 - val_fp: 159.0000 - val_tn: 26364.0000 - val_fn: 1408.0000 - val_accuracy: 0.9508 - val_precision: 0.9610 - val_recall: 0.7356 - val_auc: 0.9570
# Epoch 42/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1781 - tp: 4542.0000 - fp: 287.0000 - tn: 32027.0000 - fn: 1941.0000 - accuracy: 0.9426 - precision: 0.9406 - recall: 0.7006 - auc: 0.9545 - val_loss: 0.1612 - val_tp: 3902.0000 - val_fp: 144.0000 - val_tn: 26379.0000 - val_fn: 1424.0000 - val_accuracy: 0.9508 - val_precision: 0.9644 - val_recall: 0.7326 - val_auc: 0.9572
# Epoch 43/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1753 - tp: 4585.0000 - fp: 279.0000 - tn: 32035.0000 - fn: 1898.0000 - accuracy: 0.9439 - precision: 0.9426 - recall: 0.7072 - auc: 0.9555 - val_loss: 0.1600 - val_tp: 3946.0000 - val_fp: 160.0000 - val_tn: 26363.0000 - val_fn: 1380.0000 - val_accuracy: 0.9516 - val_precision: 0.9610 - val_recall: 0.7409 - val_auc: 0.9570
# Epoch 44/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1726 - tp: 4580.0000 - fp: 288.0000 - tn: 32026.0000 - fn: 1903.0000 - accuracy: 0.9435 - precision: 0.9408 - recall: 0.7065 - auc: 0.9558 - val_loss: 0.1597 - val_tp: 3921.0000 - val_fp: 151.0000 - val_tn: 26372.0000 - val_fn: 1405.0000 - val_accuracy: 0.9511 - val_precision: 0.9629 - val_recall: 0.7362 - val_auc: 0.9580
# Epoch 45/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1768 - tp: 4562.0000 - fp: 303.0000 - tn: 32011.0000 - fn: 1921.0000 - accuracy: 0.9427 - precision: 0.9377 - recall: 0.7037 - auc: 0.9549 - val_loss: 0.1604 - val_tp: 3898.0000 - val_fp: 141.0000 - val_tn: 26382.0000 - val_fn: 1428.0000 - val_accuracy: 0.9507 - val_precision: 0.9651 - val_recall: 0.7319 - val_auc: 0.9581
# Epoch 46/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1742 - tp: 4554.0000 - fp: 284.0000 - tn: 32030.0000 - fn: 1929.0000 - accuracy: 0.9430 - precision: 0.9413 - recall: 0.7025 - auc: 0.9562 - val_loss: 0.1612 - val_tp: 3889.0000 - val_fp: 139.0000 - val_tn: 26384.0000 - val_fn: 1437.0000 - val_accuracy: 0.9505 - val_precision: 0.9655 - val_recall: 0.7302 - val_auc: 0.9574
# Epoch 47/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1723 - tp: 4593.0000 - fp: 292.0000 - tn: 32022.0000 - fn: 1890.0000 - accuracy: 0.9438 - precision: 0.9402 - recall: 0.7085 - auc: 0.9563 - val_loss: 0.1614 - val_tp: 3902.0000 - val_fp: 141.0000 - val_tn: 26382.0000 - val_fn: 1424.0000 - val_accuracy: 0.9509 - val_precision: 0.9651 - val_recall: 0.7326 - val_auc: 0.9571
# Epoch 48/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1733 - tp: 4561.0000 - fp: 307.0000 - tn: 32007.0000 - fn: 1922.0000 - accuracy: 0.9425 - precision: 0.9369 - recall: 0.7035 - auc: 0.9554 - val_loss: 0.1605 - val_tp: 3925.0000 - val_fp: 153.0000 - val_tn: 26370.0000 - val_fn: 1401.0000 - val_accuracy: 0.9512 - val_precision: 0.9625 - val_recall: 0.7370 - val_auc: 0.9578
# Epoch 49/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1742 - tp: 4581.0000 - fp: 284.0000 - tn: 32030.0000 - fn: 1902.0000 - accuracy: 0.9437 - precision: 0.9416 - recall: 0.7066 - auc: 0.9557 - val_loss: 0.1604 - val_tp: 3893.0000 - val_fp: 139.0000 - val_tn: 26384.0000 - val_fn: 1433.0000 - val_accuracy: 0.9506 - val_precision: 0.9655 - val_recall: 0.7309 - val_auc: 0.9575
# Epoch 50/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1739 - tp: 4593.0000 - fp: 283.0000 - tn: 32031.0000 - fn: 1890.0000 - accuracy: 0.9440 - precision: 0.9420 - recall: 0.7085 - auc: 0.9563 - val_loss: 0.1609 - val_tp: 3896.0000 - val_fp: 140.0000 - val_tn: 26383.0000 - val_fn: 1430.0000 - val_accuracy: 0.9507 - val_precision: 0.9653 - val_recall: 0.7315 - val_auc: 0.9579
# Epoch 51/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1741 - tp: 4554.0000 - fp: 289.0000 - tn: 32025.0000 - fn: 1929.0000 - accuracy: 0.9428 - precision: 0.9403 - recall: 0.7025 - auc: 0.9561 - val_loss: 0.1586 - val_tp: 3926.0000 - val_fp: 149.0000 - val_tn: 26374.0000 - val_fn: 1400.0000 - val_accuracy: 0.9514 - val_precision: 0.9634 - val_recall: 0.7371 - val_auc: 0.9585
# Epoch 52/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1737 - tp: 4549.0000 - fp: 301.0000 - tn: 32013.0000 - fn: 1934.0000 - accuracy: 0.9424 - precision: 0.9379 - recall: 0.7017 - auc: 0.9554 - val_loss: 0.1596 - val_tp: 3914.0000 - val_fp: 132.0000 - val_tn: 26391.0000 - val_fn: 1412.0000 - val_accuracy: 0.9515 - val_precision: 0.9674 - val_recall: 0.7349 - val_auc: 0.9580
# Epoch 53/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1715 - tp: 4553.0000 - fp: 284.0000 - tn: 32030.0000 - fn: 1930.0000 - accuracy: 0.9429 - precision: 0.9413 - recall: 0.7023 - auc: 0.9569 - val_loss: 0.1575 - val_tp: 3937.0000 - val_fp: 144.0000 - val_tn: 26379.0000 - val_fn: 1389.0000 - val_accuracy: 0.9519 - val_precision: 0.9647 - val_recall: 0.7392 - val_auc: 0.9587
# Epoch 54/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1709 - tp: 4559.0000 - fp: 298.0000 - tn: 32016.0000 - fn: 1924.0000 - accuracy: 0.9427 - precision: 0.9386 - recall: 0.7032 - auc: 0.9571 - val_loss: 0.1597 - val_tp: 3915.0000 - val_fp: 134.0000 - val_tn: 26389.0000 - val_fn: 1411.0000 - val_accuracy: 0.9515 - val_precision: 0.9669 - val_recall: 0.7351 - val_auc: 0.9581
# Epoch 55/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1692 - tp: 4590.0000 - fp: 300.0000 - tn: 32014.0000 - fn: 1893.0000 - accuracy: 0.9435 - precision: 0.9387 - recall: 0.7080 - auc: 0.9570 - val_loss: 0.1593 - val_tp: 3914.0000 - val_fp: 141.0000 - val_tn: 26382.0000 - val_fn: 1412.0000 - val_accuracy: 0.9512 - val_precision: 0.9652 - val_recall: 0.7349 - val_auc: 0.9582
# Epoch 56/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1706 - tp: 4583.0000 - fp: 313.0000 - tn: 32001.0000 - fn: 1900.0000 - accuracy: 0.9430 - precision: 0.9361 - recall: 0.7069 - auc: 0.9575 - val_loss: 0.1589 - val_tp: 3936.0000 - val_fp: 150.0000 - val_tn: 26373.0000 - val_fn: 1390.0000 - val_accuracy: 0.9516 - val_precision: 0.9633 - val_recall: 0.7390 - val_auc: 0.9582
# Epoch 57/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1690 - tp: 4596.0000 - fp: 304.0000 - tn: 32010.0000 - fn: 1887.0000 - accuracy: 0.9435 - precision: 0.9380 - recall: 0.7089 - auc: 0.9571 - val_loss: 0.1574 - val_tp: 3932.0000 - val_fp: 141.0000 - val_tn: 26382.0000 - val_fn: 1394.0000 - val_accuracy: 0.9518 - val_precision: 0.9654 - val_recall: 0.7383 - val_auc: 0.9588
# Epoch 58/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1694 - tp: 4621.0000 - fp: 291.0000 - tn: 32023.0000 - fn: 1862.0000 - accuracy: 0.9445 - precision: 0.9408 - recall: 0.7128 - auc: 0.9569 - val_loss: 0.1589 - val_tp: 3920.0000 - val_fp: 144.0000 - val_tn: 26379.0000 - val_fn: 1406.0000 - val_accuracy: 0.9513 - val_precision: 0.9646 - val_recall: 0.7360 - val_auc: 0.9584
# Epoch 59/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1674 - tp: 4613.0000 - fp: 272.0000 - tn: 32042.0000 - fn: 1870.0000 - accuracy: 0.9448 - precision: 0.9443 - recall: 0.7116 - auc: 0.9582 - val_loss: 0.1582 - val_tp: 3930.0000 - val_fp: 154.0000 - val_tn: 26369.0000 - val_fn: 1396.0000 - val_accuracy: 0.9513 - val_precision: 0.9623 - val_recall: 0.7379 - val_auc: 0.9591
# Epoch 60/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1702 - tp: 4577.0000 - fp: 289.0000 - tn: 32025.0000 - fn: 1906.0000 - accuracy: 0.9434 - precision: 0.9406 - recall: 0.7060 - auc: 0.9568 - val_loss: 0.1578 - val_tp: 3932.0000 - val_fp: 148.0000 - val_tn: 26375.0000 - val_fn: 1394.0000 - val_accuracy: 0.9516 - val_precision: 0.9637 - val_recall: 0.7383 - val_auc: 0.9591
# Epoch 61/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1668 - tp: 4615.0000 - fp: 284.0000 - tn: 32030.0000 - fn: 1868.0000 - accuracy: 0.9445 - precision: 0.9420 - recall: 0.7119 - auc: 0.9582 - val_loss: 0.1577 - val_tp: 3923.0000 - val_fp: 140.0000 - val_tn: 26383.0000 - val_fn: 1403.0000 - val_accuracy: 0.9516 - val_precision: 0.9655 - val_recall: 0.7366 - val_auc: 0.9581
# Epoch 62/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1676 - tp: 4593.0000 - fp: 295.0000 - tn: 32019.0000 - fn: 1890.0000 - accuracy: 0.9437 - precision: 0.9396 - recall: 0.7085 - auc: 0.9584 - val_loss: 0.1592 - val_tp: 3918.0000 - val_fp: 141.0000 - val_tn: 26382.0000 - val_fn: 1408.0000 - val_accuracy: 0.9514 - val_precision: 0.9653 - val_recall: 0.7356 - val_auc: 0.9583
# Epoch 63/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1688 - tp: 4600.0000 - fp: 280.0000 - tn: 32034.0000 - fn: 1883.0000 - accuracy: 0.9442 - precision: 0.9426 - recall: 0.7095 - auc: 0.9576 - val_loss: 0.1570 - val_tp: 3942.0000 - val_fp: 148.0000 - val_tn: 26375.0000 - val_fn: 1384.0000 - val_accuracy: 0.9519 - val_precision: 0.9638 - val_recall: 0.7401 - val_auc: 0.9585
# Epoch 64/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1661 - tp: 4617.0000 - fp: 300.0000 - tn: 32014.0000 - fn: 1866.0000 - accuracy: 0.9442 - precision: 0.9390 - recall: 0.7122 - auc: 0.9580 - val_loss: 0.1586 - val_tp: 3917.0000 - val_fp: 139.0000 - val_tn: 26384.0000 - val_fn: 1409.0000 - val_accuracy: 0.9514 - val_precision: 0.9657 - val_recall: 0.7354 - val_auc: 0.9590
# Epoch 65/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1672 - tp: 4593.0000 - fp: 270.0000 - tn: 32044.0000 - fn: 1890.0000 - accuracy: 0.9443 - precision: 0.9445 - recall: 0.7085 - auc: 0.9582 - val_loss: 0.1575 - val_tp: 3934.0000 - val_fp: 151.0000 - val_tn: 26372.0000 - val_fn: 1392.0000 - val_accuracy: 0.9516 - val_precision: 0.9630 - val_recall: 0.7386 - val_auc: 0.9592
# Epoch 66/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1699 - tp: 4590.0000 - fp: 300.0000 - tn: 32014.0000 - fn: 1893.0000 - accuracy: 0.9435 - precision: 0.9387 - recall: 0.7080 - auc: 0.9582 - val_loss: 0.1579 - val_tp: 3914.0000 - val_fp: 144.0000 - val_tn: 26379.0000 - val_fn: 1412.0000 - val_accuracy: 0.9511 - val_precision: 0.9645 - val_recall: 0.7349 - val_auc: 0.9584
# Epoch 67/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1677 - tp: 4586.0000 - fp: 315.0000 - tn: 31999.0000 - fn: 1897.0000 - accuracy: 0.9430 - precision: 0.9357 - recall: 0.7074 - auc: 0.9584 - val_loss: 0.1598 - val_tp: 3907.0000 - val_fp: 135.0000 - val_tn: 26388.0000 - val_fn: 1419.0000 - val_accuracy: 0.9512 - val_precision: 0.9666 - val_recall: 0.7336 - val_auc: 0.9579
# Epoch 68/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1699 - tp: 4595.0000 - fp: 297.0000 - tn: 32017.0000 - fn: 1888.0000 - accuracy: 0.9437 - precision: 0.9393 - recall: 0.7088 - auc: 0.9574 - val_loss: 0.1592 - val_tp: 3914.0000 - val_fp: 145.0000 - val_tn: 26378.0000 - val_fn: 1412.0000 - val_accuracy: 0.9511 - val_precision: 0.9643 - val_recall: 0.7349 - val_auc: 0.9583
# Epoch 69/100
# 1213/1213 [==============================] - 4s 3ms/step - loss: 0.1696 - tp: 4607.0000 - fp: 281.0000 - tn: 32033.0000 - fn: 1876.0000 - accuracy: 0.9444 - precision: 0.9425 - recall: 0.7106 - auc: 0.9576 - val_loss: 0.1576 - val_tp: 3920.0000 - val_fp: 153.0000 - val_tn: 26370.0000 - val_fn: 1406.0000 - val_accuracy: 0.9511 - val_precision: 0.9624 - val_recall: 0.7360 - val_auc: 0.9587
# Epoch 70/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1685 - tp: 4585.0000 - fp: 297.0000 - tn: 32017.0000 - fn: 1898.0000 - accuracy: 0.9434 - precision: 0.9392 - recall: 0.7072 - auc: 0.9591 - val_loss: 0.1585 - val_tp: 3941.0000 - val_fp: 150.0000 - val_tn: 26373.0000 - val_fn: 1385.0000 - val_accuracy: 0.9518 - val_precision: 0.9633 - val_recall: 0.7400 - val_auc: 0.9581
# Epoch 71/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1688 - tp: 4606.0000 - fp: 295.0000 - tn: 32019.0000 - fn: 1877.0000 - accuracy: 0.9440 - precision: 0.9398 - recall: 0.7105 - auc: 0.9580 - val_loss: 0.1599 - val_tp: 3900.0000 - val_fp: 139.0000 - val_tn: 26384.0000 - val_fn: 1426.0000 - val_accuracy: 0.9509 - val_precision: 0.9656 - val_recall: 0.7323 - val_auc: 0.9579
# Epoch 72/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1677 - tp: 4603.0000 - fp: 299.0000 - tn: 32015.0000 - fn: 1880.0000 - accuracy: 0.9438 - precision: 0.9390 - recall: 0.7100 - auc: 0.9584 - val_loss: 0.1590 - val_tp: 3914.0000 - val_fp: 149.0000 - val_tn: 26374.0000 - val_fn: 1412.0000 - val_accuracy: 0.9510 - val_precision: 0.9633 - val_recall: 0.7349 - val_auc: 0.9584
# Epoch 73/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1660 - tp: 4596.0000 - fp: 297.0000 - tn: 32017.0000 - fn: 1887.0000 - accuracy: 0.9437 - precision: 0.9393 - recall: 0.7089 - auc: 0.9594 - val_loss: 0.1599 - val_tp: 3907.0000 - val_fp: 148.0000 - val_tn: 26375.0000 - val_fn: 1419.0000 - val_accuracy: 0.9508 - val_precision: 0.9635 - val_recall: 0.7336 - val_auc: 0.9581
# Epoch 74/100
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1665 - tp: 4595.0000 - fp: 304.0000 - tn: 32010.0000 - fn: 1888.0000 - accuracy: 0.9435 - precision: 0.9379 - recall: 0.7088 - auc: 0.9584 - val_loss: 0.1577 - val_tp: 3933.0000 - val_fp: 156.0000 - val_tn: 26367.0000 - val_fn: 1393.0000 - val_accuracy: 0.9514 - val_precision: 0.9618 - val_recall: 0.7385 - val_auc: 0.9588
# Epoch 75/100
# 1208/1213 [============================>.] - ETA: 0s - loss: 0.1683 - tp: 4592.0000 - fp: 304.0000 - tn: 31885.0000 - fn: 1875.0000 - accuracy: 0.9436 - precision: 0.9379 - recall: 0.7101 - auc: 0.9590Restoring model weights from the end of the best epoch.
# 1213/1213 [==============================] - 3s 3ms/step - loss: 0.1681 - tp: 4602.0000 - fp: 305.0000 - tn: 32009.0000 - fn: 1881.0000 - accuracy: 0.9437 - precision: 0.9378 - recall: 0.7099 - auc: 0.9590 - val_loss: 0.1571 - val_tp: 3937.0000 - val_fp: 149.0000 - val_tn: 26374.0000 - val_fn: 1389.0000 - val_accuracy: 0.9517 - val_precision: 0.9635 - val_recall: 0.7392 - val_auc: 0.9589
# Epoch 00075: early stopping

# %%
import matplotlib.pyplot as plt
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.rcParams['figure.figsize'] = (12, 10)

#Plot metrics
def plot_metrics(history):
  metrics =  ['loss', 'auc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()
plot_metrics(baseline_history)

# %% [markdown]
# ##Dimensionality Reduction with TruncatedSVD

# %%
from sklearn.decomposition import TruncatedSVD
# fit and transform data
svd = TruncatedSVD(n_components=5, n_iter=7, random_state=42)
svd.fit(X_train) 
svd.fit(X_test)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=5, n_iter=7, random_state=42,
#              tol=0.0)

# %%
from sklearn.metrics import silhouette_score
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

X_train2 = X_train.copy()

tsne = TSNE(n_components=3, verbose=1, perplexity=50, n_iter=500, learning_rate=200)
tsne_scale_results = tsne.fit_transform(X_train2)
tsne_df_scale = pd.DataFrame(tsne_scale_results, columns=['tsne1', 'tsne2', 'tsne3'])

kmeans_tsne_scale = KMeans(n_clusters=4, n_init=100, max_iter=400, init='k-means++', random_state=42).fit(tsne_df_scale)
print('KMeans tSNE Scaled Silhouette Score: {}'.format(silhouette_score(tsne_df_scale, kmeans_tsne_scale.labels_, metric='euclidean')))
labels_tsne_scale = kmeans_tsne_scale.labels_
clusters_tsne_scale = pd.concat([tsne_df_scale, pd.DataFrame({'tsne_clusters':labels_tsne_scale})], axis=1)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 38797 samples in 0.002s...
# [t-SNE] Computed neighbors for 38797 samples in 50.443s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 38797
# [t-SNE] Computed conditional probabilities for sample 2000 / 38797
# [t-SNE] Computed conditional probabilities for sample 3000 / 38797
# [t-SNE] Computed conditional probabilities for sample 4000 / 38797
# [t-SNE] Computed conditional probabilities for sample 5000 / 38797
# [t-SNE] Computed conditional probabilities for sample 6000 / 38797
# [t-SNE] Computed conditional probabilities for sample 7000 / 38797
# [t-SNE] Computed conditional probabilities for sample 8000 / 38797
# [t-SNE] Computed conditional probabilities for sample 9000 / 38797
# [t-SNE] Computed conditional probabilities for sample 10000 / 38797
# [t-SNE] Computed conditional probabilities for sample 11000 / 38797
# [t-SNE] Computed conditional probabilities for sample 12000 / 38797
# [t-SNE] Computed conditional probabilities for sample 13000 / 38797
# [t-SNE] Computed conditional probabilities for sample 14000 / 38797
# [t-SNE] Computed conditional probabilities for sample 15000 / 38797
# [t-SNE] Computed conditional probabilities for sample 16000 / 38797
# [t-SNE] Computed conditional probabilities for sample 17000 / 38797
# [t-SNE] Computed conditional probabilities for sample 18000 / 38797
# [t-SNE] Computed conditional probabilities for sample 19000 / 38797
# [t-SNE] Computed conditional probabilities for sample 20000 / 38797
# [t-SNE] Computed conditional probabilities for sample 21000 / 38797
# [t-SNE] Computed conditional probabilities for sample 22000 / 38797
# [t-SNE] Computed conditional probabilities for sample 23000 / 38797
# [t-SNE] Computed conditional probabilities for sample 24000 / 38797
# [t-SNE] Computed conditional probabilities for sample 25000 / 38797
# [t-SNE] Computed conditional probabilities for sample 26000 / 38797
# [t-SNE] Computed conditional probabilities for sample 27000 / 38797
# [t-SNE] Computed conditional probabilities for sample 28000 / 38797
# [t-SNE] Computed conditional probabilities for sample 29000 / 38797
# [t-SNE] Computed conditional probabilities for sample 30000 / 38797
# [t-SNE] Computed conditional probabilities for sample 31000 / 38797
# [t-SNE] Computed conditional probabilities for sample 32000 / 38797
# [t-SNE] Computed conditional probabilities for sample 33000 / 38797
# [t-SNE] Computed conditional probabilities for sample 34000 / 38797
# [t-SNE] Computed conditional probabilities for sample 35000 / 38797
# [t-SNE] Computed conditional probabilities for sample 36000 / 38797
# [t-SNE] Computed conditional probabilities for sample 37000 / 38797
# [t-SNE] Computed conditional probabilities for sample 38000 / 38797
# [t-SNE] Computed conditional probabilities for sample 38797 / 38797
# [t-SNE] Mean sigma: 0.689852
# [t-SNE] KL divergence after 50 iterations with early exaggeration: 109.059097
# [t-SNE] KL divergence after 500 iterations: 2.169923
# KMeans tSNE Scaled Silhouette Score: 0.2571689188480377

# %%
from sklearn.cluster import KMeans
sse = []
k_list = range(1, 15)
for k in k_list:
    km = KMeans(n_clusters=k)
    km.fit(X_train2)
    sse.append([k, km.inertia_])
    
tsne_results_scale = pd.DataFrame({'Cluster': range(1,15), 'SSE': sse})
plt.figure(figsize=(12,6))
plt.plot(pd.DataFrame(sse)[0], pd.DataFrame(sse)[1], marker='o')
plt.title('Optimal Number of Clusters using Elbow Method (tSNE_Scaled Data)')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
# Out:
# Text(0, 0.5, 'Inertia')

# %%
import plotly.graph_objs as go

Scene = dict(xaxis = dict(title  = 'tsne1'),yaxis = dict(title  = 'tsne2'),zaxis = dict(title  = 'tsne3'))
labels = labels_tsne_scale
trace = go.Scatter3d(x=clusters_tsne_scale.iloc[:,0], y=clusters_tsne_scale.iloc[:,2], z=clusters_tsne_scale.iloc[:,1], mode='markers',marker=dict(color = labels, colorscale='Viridis', size = 10, line = dict(color = 'yellow',width = 5)))
layout = go.Layout(margin=dict(l=0,r=0),scene = Scene, height = 1000,width = 1000)
data = [trace]
fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="82bbdfc4-afdd-4d33-82e0-c1432ee22446" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("82bbdfc4-afdd-4d33-82e0-c1432ee22446")) {
#                     Plotly.newPlot(
#                         '82bbdfc4-afdd-4d33-82e0-c1432ee22446',
#                         [{"marker": {"color": [3, 3, 3, 2, 1, 2, 0, 1, 3, 2, 1, 1, 2, 1, 3, 1, 1, 1, 0, 1, 1, 3, 1, 2, 1, 3, 1, 1, 2, 0, 2, 1, 3, 3, 0, 3, 0, 3, 2, 0, 2, 1, 2, 0, 2, 2, 0, 3, 2, 0, 1, 2, 3, 0, 1, 0, 3, 0, 3, 2, 1, 1, 2, 2, 1, 1, 0, 0, 1, 1, 2, 3, 0, 3, 1, 2, 2, 3, 0, 2, 1, 3, 3, 0, 3, 3, 3, 2, 2, 1, 3, 0, 0, 2, 3, 0, 2, 2, 3, 0, 2, 2, 0, 3, 1, 3, 3, 2, 1, 2, 3, 2, 2, 1, 0, 2, 0, 1, 1, 0, 1, 2, 1, 0, 1, 1, 2, 2, 2, 3, 2, 1, 2, 2, 1, 3, 0, 1, 1, 2, 2, 3, 0, 3, 1, 0, 2, 3, 2, 2, 1, 0, 2, 3, 0, 0, 3, 1, 2, 1, 0, 1, 2, 0, 1, 0, 1, 0, 2, 1, 1, 3, 1, 1, 2, 1, 2, 0, 0, 1, 0, 3, 2, 2, 3, 0, 2, 1, 3, 1, 2, 3, 0, 0, 0, 3, 1, 1, 3, 1, 1, 1, 0, 1, 1, 0, 3, 2, 2, 1, 0, 1, 3, 3, 0, 2, 0, 2, 0, 0, 1, 1, 2, 1, 2, 2, 2, 1, 0, 2, 2, 2, 1, 2, 3, 1, 3, 0, 1, 1, 0, 0, 2, 2, 3, 1, 1, 1, 2, 3, 3, 1, 2, 2, 2, 3, 1, 1, 2, 2, 3, 1, 1, 2, 2, 3, 2, 2, 2, 2, 2, 0, 2, 2, 1, 2, 1, 2, 2, 3, 2, 3, 0, 2, 0, 3, 2, 2, 0, 0, 1, 2, 1, 0, 1, 3, 2, 0, 0, 2, 1, 0, 1, 0, 3, 0, 3, 2, 0, 0, 3, 3, 3, 2, 1, 0, 2, 1, 2, 2, 1, 3, 2, 0, 0, 1, 0, 0, 0, 1, 2, 3, 1, 1, 0, 3, 0, 2, 1, 3, 3, 1, 1, 3, 0, 2, 1, 2, 0, 1, 1, 2, 0, 2, 1, 0, 0, 3, 3, 0, 0, 3, 3, 3, 0, 2, 3, 1, 1, 2, 0, 1, 3, 2, 1, 1, 3, 2, 2, 3, 2, 3, 0, 3, 2, 3, 2, 1, 3, 3, 3, 0, 1, 0, 3, 1, 3, 0, 2, 0, 3, 2, 0, 3, 1, 3, 2, 3, 0, 2, 0, 2, 3, 3, 1, 3, 0, 1, 0, 1, 0, 3, 0, 1, 3, 0, 3, 1, 1, 0, 0, 3, 3, 1, 0, 3, 1, 1, 0, 3, 0, 2, 3, 0, 0, 0, 1, 2, 0, 3, 2, 0, 1, 2, 1, 1, 0, 0, 1, 3, 3, 3, 0, 3, 0, 1, 3, 2, 3, 3, 3, 3, 0, 3, 2, 3, 0, 1, 3, 3, 3, 3, 2, 0, 2, 2, 1, 1, 0, 1, 1, 3, 1, 3, 0, 0, 1, 0, 2, 0, 1, 3, 2, 3, 2, 2, 3, 0, 0, 2, 2, 2, 2, 3, 3, 1, 0, 0, 0, 2, 0, 0, 1, 1, 0, 0, 3, 3, 1, 0, 0, 0, 1, 3, 1, 0, 0, 3, 1, 3, 3, 2, 1, 1, 3, 3, 1, 0, 2, 1, 2, 1, 2, 1, 2, 3, 2, 3, 1, 1, 0, 3, 1, 0, 0, 1, 0, 1, 0, 2, 2, 2, 2, 3, 2, 1, 3, 3, 2, 1, 3, 0, 3, 0, 1, 1, 3, 0, 3, 3, 2, 0, 2, 2, 3, 0, 2, 3, 1, 0, 1, 2, 3, 3, 2, 2, 2, 2, 3, 2, 3, 1, 0, 2, 1, 1, 2, 0, 3, 2, 2, 1, 3, 3, 2, 2, 0, 1, 2, 0, 1, 1, 0, 2, 2, 0, 0, 0, 1, 3, 3, 0, 1, 2, 3, 1, 0, 0, 3, 3, 1, 3, 0, 2, 3, 2, 2, 3, 2, 1, 3, 2, 1, 3, 2, 2, 2, 1, 1, 0, 1, 2, 3, 3, 3, 1, 1, 1, 1, 3, 0, 3, 3, 2, 2, 3, 2, 0, 1, 0, 0, 1, 1, 0, 2, 3, 0, 0, 3, 2, 1, 3, 1, 2, 0, 3, 2, 3, 0, 0, 3, 2, 2, 0, 3, 3, 2, 0, 1, 0, 0, 0, 3, 0, 2, 2, 0, 3, 0, 3, 3, 1, 2, 3, 2, 0, 2, 0, 2, 1, 0, 0, 0, 0, 3, 1, 1, 1, 1, 2, 3, 3, 2, 1, 1, 1, 0, 3, 2, 2, 3, 0, 2, 0, 2, 0, 1, 3, 3, 0, 0, 3, 3, 1, 3, 3, 2, 3, 2, 1, 1, 1, 1, 1, 0, 3, 3, 1, 2, 3, 0, 0, 0, 1, 2, 2, 0, 3, 2, 0, 2, 2, 2, 2, 0, 2, 1, 3, 2, 0, 0, 3, 3, 1, 3, 0, 2, 3, 2, 2, 1, 3, 1, 3, 0, 1, 0, 1, 3, 0, 0, 0, 1, 3, 3, 0, 3, 3, 0, 0, 1, 3, 3, 0, 1, 2, 2, 1, 3, 3, 2, 2, 0, 2, 3, 3, 0, 2, 2, 0, 2, 1, 1, 3, 1, 0, 0, 0, 0, 1, 3, 3, 3, 2, 0, 2, 1, 0, 0, 0, 1, 3, 0, 0, 0, 0, 1, 3, 0, 2, 1, 3, 0, 3, 3, 0, 2, 2, 1, 0, 2, 1, 3, 1, 1, 2, 3, 1, 3, 2, 2, 3, 0, 3, 0, 3, 3, 0, 0, 3, 3, 0, 1, 3, 0, 1, 2, 3, 2, 2, 2, 2, 0, 1, 1, 0, 3, 1, 0, 1, 2, 1, 2, 0, 0, 0, 1, 0, 0, 3, 2, 1, 0, 1, 2, 2, 0, 0, 0, 2, 2, 2, 0, 0, 2, 1, 0, 2, 3, 0, 0, 3, 0, 2, 2, 3, 0, 1, 2, 3, 0, 0, 0, 2, 0, 3, 3, 2, 1, 1, 1, 1, 2, 2, 1, 3, 2, 2, 3, 0, 0, 3, 0, 1, 1, 0, 0, 0, 3, 1, 2, 2, 0, 1, 0, 2, 0, 1, 1, 3, 3, 2, 1, 1, 3, 2, 3, 1, 1, 1, 2, 3, 0, 0, 1, 3, 0, 3, 0, 2, 3, 0, 0, 2, 1, 2, 3, 2, 0, 2, 3, 2, 0, 2, 1, 0, 0, 2, 3, 2, 2, 1, 0, 2, 3, 2, 0, 2, 2, 2, 2, 3, 2, 2, 0, 1, 1, 2, 3, 2, 2, 0, 3, 3, 2, 0, 1, 3, 0, 1, 2, 2, 3, 2, 3, 2, 3, 2, 3, 2, 2, 1, 3, 3, 1, 1, 0, 1, 0, 2, 0, 1, 3, 3, 1, 2, 0, 2, 1, 1, 3, 2, 1, 3, 0, 3, 2, 2, 1, 0, 0, 2, 1, 1, 1, 1, 1, 0, 3, 1, 2, 1, 0, 3, 1, 3, 2, 3, 1, 1, 1, 2, 3, 1, 0, 1, 2, 3, 1, 0, 1, 1, 3, 0, 1, 3, 2, 0, 1, 0, 2, 3, 0, 3, 3, 2, 1, 1, 2, 3, 2, 1, 0, 3, 3, 3, 0, 2, 3, 3, 1, 3, 3, 3, 1, 0, 2, 3, 2, 1, 2, 3, 3, 3, 2, 2, 3, 1, 0, 0, 0, 2, 0, 1, 0, 1, 2, 1, 2, 3, 2, 0, 2, 2, 2, 3, 3, 3, 3, 3, 0, 2, 1, 3, 1, 2, 3, 0, 0, 2, 1, 1, 1, 0, 3, 0, 3, 3, 3, 3, 2, 0, 0, 1, 3, 0, 2, 0, 0, 2, 2, 3, 1, 1, 3, 3, 0, 1, 0, 1, 1, 1, 2, 1, 1, 1, 2, 3, 0, 2, 2, 1, 0, 2, 1, 3, 3, 0, 0, 0, 1, 0, 3, 0, 0, 1, 1, 3, 0, 0, 2, 0, 0, 1, 1, 3, 0, 2, 1, 3, 3, 1, 0, 0, 0, 1, 1, 1, ...

# %% [markdown]
# #Outlier Detection

# %% [markdown]
# ### LOF W/ TRUNCATED SVD
#
# I've read so many articles about how LOF is one of the most popular algorithms for anomaly detection, but usually it is used in a semi-supervised learning model. Here by itself, it appears to be less than effective.

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(n_neighbors=4, novelty=True)
lof.fit(X_train)
# Out:
# LocalOutlierFactor(algorithm='auto', contamination='auto', leaf_size=30,
#                    metric='minkowski', metric_params=None, n_jobs=None,
#                    n_neighbors=4, novelty=True, p=2)

# %%
from sklearn.neighbors import LocalOutlierFactor

lof = LocalOutlierFactor(n_neighbors=40, novelty=True)
lof.fit(X_train)
# Out:
# LocalOutlierFactor(algorithm='auto', contamination='auto', leaf_size=30,
#                    metric='minkowski', metric_params=None, n_jobs=None,
#                    n_neighbors=40, novelty=True, p=2)

# %%
prediction = lof.predict(X_train)
prediction[prediction==1] = 0
prediction[prediction==-1] = 1

# %%
from sklearn.metrics import f1_score

f1_score(y_train, prediction)
# Out:
# 0.0

# %%
prediction = lof.predict(X_test)
prediction[prediction==1] = 0
prediction[prediction==-1] = 1

# %%
f1_score(y_test, prediction)
# Out:
# 0.0

# %%
import seaborn as sns
plt.rcParams['figure.figsize'] = (5, 5)
#Get the confusion matrix
cf_matrix = confusion_matrix(y_test, prediction)
sns.heatmap(cf_matrix, annot=True, fmt='d')

# %% [markdown]
# #### Isolation Forest

# %%
from sklearn.ensemble import IsolationForest

ifrst = IsolationForest(random_state=32)
ifrst.fit(X_train)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False, contamination='auto',
#                 max_features=1.0, max_samples='auto', n_estimators=100,
#                 n_jobs=None, random_state=32, verbose=0, warm_start=False)

# %%
prediction = ifrst.predict(X_train)
np.unique(prediction)
# Out:
# array([1])

# %%
prediction[prediction==1] = 0
prediction[prediction==-1] = 1

f1_score(y_train, prediction)
# Out:
# 0.0

# %%
prediction = lof.predict(X_test)
prediction[prediction==1] = 0
prediction[prediction==-1] = 1

# %%
f1_score(y_test, prediction)
# Out:
# 0.0

# %%
#Get the confusion matrix
cf_matrix = confusion_matrix(y_test, prediction)
sns.heatmap(cf_matrix, annot=True, fmt='d')

# %% [markdown]
# #Best performing model

# %% [markdown]
# #### Random Forest (Normal with GridsearchCV Parameter Tuned Configuration)

# %%
# Best Parameters :  {'criterion': 'entropy', 'n_estimators': 60}
rndf_clf = RandomForestClassifier(criterion = 'entropy', n_estimators= 60, random_state=32)
rndf_clf.fit(X_train, y_train.ravel())
acc_normal.append(rndf_clf.score(X_test, y_test))
rndf_clf.score(X_test, y_test)

y_pred=rndf_clf.predict(X_test)

# %%
print('*These are the metrics for the best performing model.* \n')
print("Confusion Matrix: ") 
print(confusion_matrix(y_test, y_pred)) 
print('')

print ("Accuracy : ")
print(accuracy_score(y_test, y_pred)*100) 
print('')

print("Report : ")
print(classification_report(y_test, y_pred))
# Out:
# *These are the metrics for the best performing model.*
#
# Confusion Matrix:
# [[21732     0]
#  [    0  4325]]
#
# Accuracy :
# 100.0
#
# Report :
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     21732
#            1       1.00      1.00      1.00      4325
#
#     accuracy                           1.00     26057
#    macro avg       1.00      1.00      1.00     26057
# weighted avg       1.00      1.00      1.00     26057

# %% [markdown]
# #Conclusion
#
# Fraud detection is a very important and expensive problem is needed by literally any company on earth that handles the exchange of currency.
# According to the Nilson Report for global statistics, fraud losses worldwide reached $27.85 billion in 2018, and are expected to rise about 28% year over year over the next 4 years. <br>
# Several algorithms have been implemented on same data set to detect the credit cards frauds. All the algorithms have been analyzed and compared on basis of accuracy on basis of predicting normal cases and outliers or frauds. I  implemented different type of algorithms which include neural network from deep learning, anomaly detection algorithms like isolation forest, Local Outlier Factor, classification algorithms like Random Forest, Extre trees, etc.. This was done to attain the best approach for the purpose.
# Upon analyzing we get to know that the Random Forest was the best perfoming model. Anomaly detection is quite difficult an in many respects if far behond the scope of basic models. Although this does not completely solve the issue of fraud detection in a way that is immediately applicable in the field as a marketable solution, this does serve as a form of research on how to manager and implement the techniques that would be step 1 of 4 in achieving that end result. In the real world, the actualy anomaly detection techniques implemented are far more sophisticated, and require research teams from the best minds in the world to solve this problem. <br><br>
# The data would need to be undersampled and combined with semi-supervised learning, some of which includes convolutionaly neural networks as a precursor to bootstrapping the creation of meta-classifiers that then are fed into supervised ensembles.  In the real world of Fin-tech the best model to date has been created by M.I.T., it's called DFS or (*Deep Feature Synthesis*) which has over 200 features and touts an F1 score of .56. <br>
#
# After trying 12 different models, I've learned that the only way I know of to improve this model would be to include semi-supervised learning. In reality this system's real world use case would be to serve as a basis for research of the subject of anomaly detection.

# %% [markdown]
# ##Futurework
#
# I tried to include reverse geocoding with the latitude and longitude of the merchants and customers, in order to compare the distance between the two. It would be quite helpful to create a system that includes RFID passive synchronization that acts as a 2FA (2 factor authorization) with the user's mobile phone 'password manager', that runs in the background without any input from the user. Atlease this would cut down on the instances of stolen CC info, when a thief tries to use the stolen card at point of sale merchant, and is declined because the mobile device that syncs with the RFID cannot be detected. Any purchases that occured via the net would be weighted towards more false positives in order to increase the accuracy, with the creation of a semi-supervised learning model that uses autoencoders to create meta-classifiers, and specialized features that could be added on models as the types of fraud changed over time.
